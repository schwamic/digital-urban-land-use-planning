# %% [markdown]
# # 2.1 Planzeichenerklärung – OCR (GPT4o)
#
# * Zero-Shot
# * Chain-Of-Thought

# %%
from utils.parser import Parser
from utils.openai import OpenAI

instructions = "Du bist ein Assistent um Textinformationen aus einer Planzeichnung eines Bebauungsplans zu extrahieren."
ava = OpenAI(instructions)
jarvis = OpenAI(instructions)
samantha = OpenAI(instructions)
parser = Parser()

# %%
# Zeichenerklärung (FULL SIZE, RAW)
ze_path = "../data/processed/bpläne/2_zeichnung_textteil_getrennt/F11-01-ZE-raw.png"
base64_ze, img_size = parser.imageToBase64(ze_path)
print(img_size)

msg1 = ava.request([
    {
        "type": "text",
        "text": 'Gehe Schritt für Schritt vor: 1. Finde den Eintrag "Nutzungsschablone" in der vorliegenden Zeichenerklärung. 2. Finde die zugehörige Tabellenerklärung zum Eintrag "Nutzungsschablone". 3. Gebe die Tabellenerklärung in ASCII-Tabellenform aus.'
    },
    {
        "type": "image_url",
        "image_url": {
            "url": f"data:image/jpeg;base64,{base64_ze}",
            "detail": "high"
        }
    },
])

print(msg1)
# Out:
# [4625, 8208]
# 1. **Finde den Eintrag "Nutzungsschablone" in der vorliegenden Zeichenerklärung:**
#
# Der Eintrag "Nutzungsschablone" befindet sich in der Zeichenerklärung unter der Überschrift "Planungsrechtliche Festsetzungen".
#
# 2. **Finde die zugehörige Tabellenerklärung zum Eintrag "Nutzungsschablone":**
#
# Die Tabellenerklärung zum Eintrag "Nutzungsschablone" ist direkt unter dem Eintrag zu finden. Sie enthält die Symbole und deren Bedeutungen.
#
# 3. **Gebe die Tabellenerklärung in ASCII-Tabellenform aus:**
#
# Hier ist die Tabellenerklärung in ASCII-Tabellenform:
#
# ```
# +-------------------+------------------------------------------+
# | Symbol            | Bedeutung                                |
# +-------------------+------------------------------------------+
# | G                 | Gewerbegebiete (§ 8 BauNVO)              |
# | GE                | Gewerbegebiete eingeschränkt (§ 8 BauNVO)|
# +-------------------+------------------------------------------+
# ```
#
# Diese Tabelle zeigt die Symbole und deren Bedeutungen für die Nutzungsschablone.

# %%
# PZE (SCALED)
ze_path = "../data/processed/bpläne/2_zeichnung_textteil_getrennt/F11-01-ZE.png"
base64_ze, img_size = parser.imageToBase64(ze_path)
print("image_size:", img_size)

msg2 = ava.request([
    {
        "type": "text",
        "text": 'Gehe Schritt für Schritt vor: 1. Finde den Eintrag "Nutzungsschablone" in der vorliegenden Zeichenerklärung. 2. Finde die zugehörige Tabellenerklärung zum Eintrag "Nutzungsschablone". 3. Gebe die Tabellenerklärung in ASCII-Tabellenform aus.'
    },
    {
        "type": "image_url",
        "image_url": {
            "url": f"data:image/jpeg;base64,{base64_ze}",
            "detail": "high"
        }
    },
])

print(msg2)
# Out:
# image_size: [768, 1362]
# 1. **Finde den Eintrag "Nutzungsschablone" in der vorliegenden Zeichenerklärung:**
#
# Der Eintrag "Nutzungsschablone" befindet sich in der Zeichenerklärung unter der Kategorie "Art der Nutzung".
#
# 2. **Finde die zugehörige Tabellenerklärung zum Eintrag "Nutzungsschablone":**
#
# Die Tabellenerklärung zum Eintrag "Nutzungsschablone" ist direkt unter dem Eintrag zu finden und lautet:
# - Nutzungsschablone (§ 9 (1) 1 BauGB)
#
# 3. **Gebe die Tabellenerklärung in ASCII-Tabellenform aus:**
#
# ```plaintext
# +-------------------+-----------------------------+
# | Nutzungsschablone | (§ 9 (1) 1 BauGB)           |
# +-------------------+-----------------------------+
# ```
#
# Dies ist die ASCII-Tabellenform der Tabellenerklärung für den Eintrag "Nutzungsschablone".

# %%
# PZE (SCALED, CROPPED)
ze_path = "../data/processed/bpläne/2_zeichnung_textteil_getrennt/F11-01-ZE-crop.png"
base64_ze, img_size = parser.imageToBase64(ze_path)
print("image_size:", img_size)

msg3 = ava.request([
    {
        "type": "text",
        "text": 'Gehe Schritt für Schritt vor: 1. Finde den Eintrag "Nutzungsschablone" in der vorliegenden Zeichenerklärung. 2. Finde die zugehörige Tabellenerklärung zum Eintrag "Nutzungsschablone". 3. Gebe die Tabellenerklärung in ASCII-Tabellenform aus.'
    },
    {
        "type": "image_url",
        "image_url": {
            "url": f"data:image/jpeg;base64,{base64_ze}",
            "detail": "high"
        }
    },
])

print(msg3)
# Out:
# image_size: [768, 1949]
# 1. Der Eintrag "Nutzungsschablone" befindet sich in der Zeichenerklärung unter "Art der Nutzung" und "Gebäudehöhe".
#
# 2. Die zugehörige Tabellenerklärung zum Eintrag "Nutzungsschablone" ist in der Tabelle direkt darunter zu finden.
#
# 3. Die Tabellenerklärung in ASCII-Tabellenform:
#
# ```
# +----------------+----------------+
# | Art der Nutzung| Gebäudehöhe    |
# +----------------+----------------+
# | Grundflächenzahl| Geschossflächen-|
# |                | zahl           |
# +----------------+----------------+
# | Bauweise       | Nutzungsschablone|
# |                | (§ 9 (1) 1 BauGB)|
# +----------------+----------------+
# ```
#
# Diese Tabelle zeigt die verschiedenen Kategorien und deren zugehörige Werte, einschließlich der Nutzungsschablone gemäß § 9 (1) 1 BauGB.

# %%
# PZE (BOUNDING BOX, CROPPED)
ze_path = "../data/processed/bpläne/2_zeichnung_textteil_getrennt/F11-01-ZE-bb-crop.png"
base64_ze, img_size = parser.imageToBase64(ze_path)
print("image_size:", img_size)

msg4 = ava.request([
    {
        "type": "text",
        "text": 'Gebe die rot umrandete Tabellenerklärung zum Eintrag Nutzungsschablone in ASCII-Tabellenform aus.'
    },
    {
        "type": "image_url",
        "image_url": {
            "url": f"data:image/jpeg;base64,{base64_ze}",
            "detail": "high"
        }
    },
])

print(msg4)
# Out:
# image_size: [763, 2000]
# Hier ist die rot umrandete Tabellenerklärung in ASCII-Tabellenform:
#
# ```
# +---------------------+------------------+
# | Art der Nutzung     | Gebäudehöhe      |
# +---------------------+------------------+
# | Grundflächenzahl    | Geschossflächen- |
# |                     | zahl             |
# +---------------------+------------------+
# | Bauweise            |                  |
# +---------------------+------------------+
# ```

# %%
# PZE (SCALED, CROPPED)
ze_path = "../data/processed/bpläne/2_zeichnung_textteil_getrennt/F11-01-ZE-crop.png"
base64_ze, img_size = parser.imageToBase64(ze_path)
print("image_size:", img_size)

ava.withContext([
    {
        "type": "text",
        "text": msg4
    }
])

msg5 = ava.request([
    {
        "type": "text",
        "text": 'Fasse alle relevanten Definitionen und Zeichen bezüglich der Parameter der ASCII-Nutzungsschablone aus der Zeichenerklärung zusammen. Ausgabe im JSON-Format: {<Parameter>: {"Definition": "", "Beispiel"=""}}'
    },
    {
        "type": "image_url",
        "image_url": {
            "url": f"data:image/jpeg;base64,{base64_ze}",
            "detail": "high"
        }
    },
])

print(msg5)
# Out:
# image_size: [768, 1949]
# ```json
# {
#   "GE": {
#     "Definition": "Gewerbegebiete (§ 8 BauNVO)",
#     "Beispiel": ""
#   },
#   "GEE": {
#     "Definition": "Gewerbegebiete eingeschränkt (§ 8 BauNVO)",
#     "Beispiel": ""
#   },
#   "GH=max.12,00": {
#     "Definition": "max. zulässige Gebäudehöhe über Erdgeschossfußbodenhöhe",
#     "Beispiel": ""
#   },
#   "0,6": {
#     "Definition": "Grundflächenzahl (GRZ) (§ 16 BauNVO)",
#     "Beispiel": ""
#   },
#   "1,2": {
#     "Definition": "Geschossflächenzahl (GFZ) (§ 16 BauNVO)",
#     "Beispiel": ""
#   },
#   "a": {
#     "Definition": "Abweichende Bauweise (§ 22 BauNVO)",
#     "Beispiel": ""
#   },
#   "Baugrenze": {
#     "Definition": "Baugrenze (§ 23 (3) BauNVO)",
#     "Beispiel": ""
#   },
#   "Umgrenzung der Flächen": {
#     "Definition": "Umgrenzung der Flächen, die von der Bebauung freizuhalten sind (§ 9 (1) 10 BauGB)",
#     "Beispiel": ""
#   },
#   "Straßenverkehrsflächen": {
#     "Definition": "Straßenverkehrsflächen (§ 9 (1) 11 BauGB)",
#     "Beispiel": ""
#   },
#   "Rad-/Gehweg, Landwirtschaftlicher Verkehr": {
#     "Definition": "Rad-/Gehweg, Landwirtschaftlicher Verkehr",
#     "Beispiel": ""
#   },
#   "Bereich ohne Ein- und Ausfahrt": {
#     "Definition": "Bereich ohne Ein- und Ausfahrt",
#     "Beispiel": ""
#   },
#   "Umspannstation": {
#     "Definition": "Umspannstation",
#     "Beispiel": ""
#   },
#   "Öffentliche Grünflächen": {
#     "Definition": "Öffentliche Grünflächen (§ 9 (1) 15 BauGB)",
#     "Beispiel": ""
#   },
#   "Umgrenzung von Flächen für Maßnahmen zum Schutz, zur Pflege und zur Entwicklung von Natur und Landschaft": {
#     "Definition": "Umgrenzung von Flächen für Maßnahmen zum Schutz, zur Pflege und zur Entwicklung von Natur und Landschaft (§ 9 (1) 20 BauGB)",
#     "Beispiel": ""
#   },
#   "Umgrenzung von Flächen zum Anpflanzen von Bäumen, Sträuchern und sonstigen Bepflanzungen": {
#     "Definition": "Umgrenzung von Flächen zum Anpflanzen von Bäumen, Sträuchern und sonstigen Bepflanzungen (§ 9 (1) 25a BauGB)",
#     "Beispiel": ""
#   },
#   "Flächen mit Bindungen für die Erhaltung von Bäumen, Sträuchern und sonstigen Bepflanzungen": {
#     "Definition": "Flächen mit Bindungen für die Erhaltung von Bäumen, Sträuchern und sonstigen Bepflanzungen (§ 9 (1) 25b BauGB)",
#     "Beispiel": ""
#   },
#   "Anpflanzen von Bäumen, Sträuchern und sonstigen Bepflanzungen": {
#     "Definition": "Anpflanzen von Bäumen, Sträuchern und sonstigen Bepflanzungen (§ 9 (1) 25a BauGB)",
#     "Beispiel": ""
#   },
#   "Mit Geh-, Fahr- und Leitungsrechten zu belastende Flächen": {
#     "Definition": "Mit Geh-, Fahr- und Leitungsrechten zu belastende Flächen (§ 9 (1) 21 BauGB)",
#     "Beispiel": ""
#   },
#   "LR1": {
#     "Definition": "LR1 = zugunsten der EVS / Strom",
#     "Beispiel": ""
#   },
#   "LR2": {
#     "Definition": "LR2 = zugunsten der EVS + Stadt / Strom und Wasser",
#     "Beispiel": ""
#   },
#   "Grenze des räumlichen Geltungsbereichs des Bebauungsplans": {
#     "Definition": "Grenze des räumlichen Geltungsbereichs des Bebauungsplans (§ 9 (7) BauGB)",
#     "Beispiel": ""
#   },
#   "Grenze des räumlichen Geltungsbereichs des Bebauungsplans 'Am Nattenbucher Weg'": {
#     "Definition": "Grenze des räumlichen Geltungsbereichs des Bebauungsplans 'Am Nattenbucher Weg'",
#     "Beispiel": ""
#   }
# }
# ```
