# %% [markdown]
# # 3. QA Agent (GPT-4o)
#
# Simplifizierte RAG Anwendung für QA-Prompts.
#
# * Prüfschritte bzgl. B-Plan L04

# %%
from utils.openai import OpenAI
from utils.parser import Parser
from utils.runner import Runner
from utils.pprint import pprint

instructions = 'Du bist ein Chat-Bot der mit Hilfe der vorliegenden Informationen Fragen beantwortet. Referenziere deine Antworten anhand der jeweiligen Kapitelnummer aus der "Zeichenerklärung" und "Textliche Festsetzungen". Helfen die gegeben Informationen nicht um eine Antwort zu formulieren, antworte mit "Das ist mir nicht bekannt".'
gerty = OpenAI(instructions)
parser = Parser()
runner = Runner()

# %% [markdown]
# ### A1) Use-Case Grübler Prüfschema (L04-01)

# %%
# Test
msg0 = gerty.request([
    {
        "type": "text", 
        "text": "Wie ist das Wetter?"
    },
])
pprint(msg0)
# Out:
# Das ist mir nicht bekannt.

# %%
# Prüfungsschritte – Mit Zuordnung des Bauvorhabens
# %store -r msg211_l04_nz msg211_l04_ze msg221_l04_nz msg231_l04_tt
context = parser.text2prompts([f'Zeichenerklärung: {msg211_l04_nz}, {msg211_l04_ze}', f'Planzeichnung: {msg221_l04_nz}', f'Textliche Festsetzungen: {msg231_l04_tt}'])
gerty.addContext(context)
def run():
    return gerty.request([
        {
          "type": "text",
          "text": "Für das Bauvorhaben ist die siebte Nutzungsschablone gültig. Gebe diese Nutzungsschablone aus."  
        },
        {
            "type": "text", 
            "text": "Welche Gebäudeart ist erlaubt?"
        },
        {
            "type": "text", 
            "text": "Ist ein Wohnhaus erlaubt?"
        },
        {
            "type": "text", 
            "text": "Welche GRZ und GFZ sind festgesetzt?"
        },
        {
            "type": "text", 
            "text": "Liegen die Werte GRZ von 0,17 und ein GFZ von 0.35 unter den maximal erlaubten Werten?"
        },
        {
            "type": "text", 
            "text": "Wieviel Vollgeschosse sind erlaubt?"
        },
        {
            "type": "text", 
            "text": "Sind zwei Vollgeschosse zulässig?"
        },
        {
            "type": "text", 
            "text": "Welche Bauweise ist festgesetzt?"
        },
        {
            "type": "text", 
            "text": "Werden die seitlichen Abstandsfläche eingehalten?"
        },
    ])
runner.consistency_check(run)
gerty.clearContext()
# Out:
# ### Nutzungsschablone 7
#
# ```json
# {
#   "Baugebiet": "WA",
#   "Zahl der Vollgeschosse": "I",
#   "Grundflächenzahl": "0,3",
#   "Geschossflächenzahl": "0,5",
#   "Bauweise": "0",
#   "Dachform und Dachneigung": "SD DN 28-33°"
# }
# ```
#
# ### Antworten
#
# 1. **Welche Gebäudeart ist erlaubt?**
#    - Erlaubt ist ein Gebäude im Allgemeinen Wohngebiet (WA) (§ 4 BauNVO). (Kapitel 1.1.1)
#
# 2. **Ist ein Wohnhaus erlaubt?**
#    - Ja, ein Wohnhaus ist erlaubt, da es sich um ein Allgemeines Wohngebiet (WA) handelt. (Kapitel 1.1.1)
#
# 3. **Welche GRZ und GFZ sind festgesetzt?**
#    - Die festgesetzte Grundflächenzahl (GRZ) ist 0,3 und die Geschossflächenzahl (GFZ) ist 0,5. (Kapitel 1.1.1)
#
# 4. **Liegen die Werte GRZ von 0,17 und ein GFZ von 0.35 unter den maximal erlaubten Werten?**
#    - Ja, die Werte GRZ von 0,17 und GFZ von 0,35 liegen unter den maximal erlaubten Werten von GRZ 0,3 und GFZ 0,5. (Kapitel 1.1.1)
#
# 5. **Wieviel Vollgeschosse sind erlaubt?**
#    - Es ist ein Vollgeschoss erlaubt. (Kapitel 1.1.3)
#
# 6. **Sind zwei Vollgeschosse zulässig?**
#    - Nein, zwei Vollgeschosse sind nicht zulässig, da nur ein Vollgeschoss erlaubt ist. (Kapitel 1.1.3)
#
# 7. **Welche Bauweise ist festgesetzt?**
#    - Die festgesetzte Bauweise ist die offene Bauweise (0). (Kapitel 1.2)
#
# 8. **Werden die seitlichen Abstandsfläche eingehalten?**
#    - Das ist mir nicht bekannt.
# #############################################
# ### Nutzungsschablone 7
#
# ```json
# {
#   "Baugebiet": "WA",
#   "Zahl der Vollgeschosse": "I",
#   "Grundflächenzahl": "0,3",
#   "Geschossflächenzahl": "0,5",
#   "Bauweise": "0",
#   "Dachform und Dachneigung": "SD DN 28-33°"
# }
# ```
#
# ### Antworten
#
# 1. **Welche Gebäudeart ist erlaubt?**
#    - Erlaubt ist ein Gebäude im Allgemeinen Wohngebiet (WA) (§ 4 BauNVO).
#
# 2. **Ist ein Wohnhaus erlaubt?**
#    - Ja, ein Wohnhaus ist erlaubt, da es sich um ein Allgemeines Wohngebiet (WA) handelt (§ 4 BauNVO).
#
# 3. **Welche GRZ und GFZ sind festgesetzt?**
#    - Die festgesetzte Grundflächenzahl (GRZ) ist 0,3 und die Geschossflächenzahl (GFZ) ist 0,5.
#
# 4. **Liegen die Werte GRZ von 0,17 und ein GFZ von 0.35 unter den maximal erlaubten Werten?**
#    - Ja, die Werte GRZ von 0,17 und GFZ von 0,35 liegen unter den maximal erlaubten Werten von GRZ 0,3 und GFZ 0,5.
#
# 5. **Wieviel Vollgeschosse sind erlaubt?**
#    - Es ist ein Vollgeschoss erlaubt.
#
# 6. **Sind zwei Vollgeschosse zulässig?**
#    - Nein, zwei Vollgeschosse sind nicht zulässig, da nur ein Vollgeschoss erlaubt ist (§ 18 BauNVO).
#
# 7. **Welche Bauweise ist festgesetzt?**
#    - Die festgesetzte Bauweise ist die offene Bauweise (0), in der nur Einzel- und Doppelhäuser zulässig sind.
#
# 8. **Werden die seitlichen Abstandsflächen eingehalten?**
#    - Das ist mir nicht bekannt. Die Einhaltung der seitlichen Abstandsflächen hängt von den spezifischen Abmessungen und der Position des Gebäudes auf dem Grundstück ab und kann nicht aus den vorliegenden Informationen abgeleitet werden.
# #############################################
# Hier sind die Informationen zur siebten Nutzungsschablone:
#
# ### Nutzungsschablone
# - **Baugebiet**: WA (Allgemeines Wohngebiet)
# - **Zahl der Vollgeschosse**: I
# - **Grundflächenzahl (GRZ)**: 0,3
# - **Geschossflächenzahl (GFZ)**: 0,5
# - **Bauweise**: 0 (Offene Bauweise)
# - **Dachform und Dachneigung**: SD DN 28-33°
#
# ### Antworten auf die Fragen:
#
# 1. **Welche Gebäudeart ist erlaubt?**
#    - Erlaubt ist ein Gebäude im Allgemeinen Wohngebiet (WA) (§ 4 BauNVO).
#
# 2. **Ist ein Wohnhaus erlaubt?**
#    - Ja, ein Wohnhaus ist erlaubt, da es sich um ein Allgemeines Wohngebiet (WA) handelt (§ 4 BauNVO).
#
# 3. **Welche GRZ und GFZ sind festgesetzt?**
#    - Die festgesetzte Grundflächenzahl (GRZ) ist 0,3 und die Geschossflächenzahl (GFZ) ist 0,5 (§ 19 und § 20 BauNVO).
#
# 4. **Liegen die Werte GRZ von 0,17 und ein GFZ von 0.35 unter den maximal erlaubten Werten?**
#    - Ja, die Werte GRZ von 0,17 und GFZ von 0.35 liegen unter den maximal erlaubten Werten von GRZ 0,3 und GFZ 0,5 (§ 19 und § 20 BauNVO).
#
# 5. **Wieviel Vollgeschosse sind erlaubt?**
#    - Es ist ein Vollgeschoss erlaubt (§ 18 BauNVO).
#
# 6. **Sind zwei Vollgeschosse zulässig?**
#    - Nein, zwei Vollgeschosse sind nicht zulässig, da nur ein Vollgeschoss erlaubt ist (§ 18 BauNVO).
#
# 7. **Welche Bauweise ist festgesetzt?**
#    - Die festgesetzte Bauweise ist die offene Bauweise (§ 22 BauNVO).
#
# 8. **Werden die seitlichen Abstandsfläche eingehalten?**
#    - Das ist mir nicht bekannt. Die Einhaltung der seitlichen Abstandsflächen hängt von den spezifischen Abständen des geplanten Gebäudes zu den Grundstücksgrenzen ab und ist nicht aus den vorliegenden Informationen ersichtlich.
# #############################################

# %%
# Prüfungsschritte – Ohne Zuordnung des Bauvorhabens
# %store -r msg211_l04_nz msg211_l04_ze msg221_l04_nz msg231_l04_tt
context = parser.text2prompts([f'Zeichenerklärung: {msg211_l04_nz}, {msg211_l04_ze}', f'Planzeichnung: {msg221_l04_nz}', f'Textliche Festsetzungen: {msg231_l04_tt}'])
gerty.addContext(context)
def run():
    return gerty.request([
        {
            "type": "text", 
            "text": "Welche Gebäudearten sind erlaubt?"
        },
        {
            "type": "text", 
            "text": "Ist ein Wohnhaus erlaubt?"
        },
        {
            "type": "text", 
            "text": "Welche GRZ und GFZ sind festgesetzt?"
        },
        {
            "type": "text", 
            "text": "Liegen die Werte GRZ von 0,17 und ein GFZ von 0.35 unter den maximal erlaubten Werten?"
        },
        {
            "type": "text", 
            "text": "Wieviel Vollgeschosse sind erlaubt?"
        },
        {
            "type": "text", 
            "text": "Sind zwei Vollgeschosse zulässig?"
        },
        {
            "type": "text", 
            "text": "Welche Bauweisen sind festgesetzt?"
        },
        {
            "type": "text", 
            "text": "Werden die seitlichen Abstandsfläche eingehalten?"
        },
        {
            "type": "text", 
            "text": "Welche Bauweise ist für Wohngebäude zulässig?"
        },
    ])
runner.consistency_check(run)
gerty.clearContext()
# Out:
# ### Welche Gebäudearten sind erlaubt? Ist ein Wohnhaus erlaubt?
#
# Die erlaubten Gebäudearten hängen vom Baugebiet ab. Es gibt verschiedene Baugebiete wie reines Wohngebiet (WR), allgemeines Wohngebiet (WA), Mischgebiet (MI) und eingeschränktes Gewerbegebiet (GE2). Ein Wohnhaus ist in den Wohngebieten (WR und WA) und im Mischgebiet (MI) erlaubt.
#
# Referenz: Zeichenerklärung und Textliche Festsetzungen, Kapitel 1.1.1
#
# ### Welche GRZ und GFZ sind festgesetzt?
#
# Die Grundflächenzahl (GRZ) und Geschossflächenzahl (GFZ) variieren je nach Baugebiet. Hier sind einige Beispiele:
#
# - **GE2**: GRZ 0,6, GFZ 1,2
# - **WA**: GRZ 0,3 bis 0,5, GFZ 0,4 bis 0,8
# - **MI**: GRZ 0,4, GFZ 0,5
# - **WR**: GRZ 0,3 bis 0,5, GFZ nicht festgesetzt
#
# Referenz: Planzeichnung
#
# ### Liegen die Werte GRZ von 0,17 und ein GFZ von 0.35 unter den maximal erlaubten Werten?
#
# Ja, die Werte GRZ von 0,17 und GFZ von 0.35 liegen unter den maximal erlaubten Werten in den meisten Baugebieten. Zum Beispiel:
#
# - In einem allgemeinen Wohngebiet (WA) ist die GRZ bis zu 0,5 und die GFZ bis zu 0,8 erlaubt.
# - In einem Mischgebiet (MI) ist die GRZ 0,4 und die GFZ 0,5 erlaubt.
#
# Referenz: Planzeichnung
#
# ### Wieviel Vollgeschosse sind erlaubt? Sind zwei Vollgeschosse zulässig?
#
# Die Anzahl der erlaubten Vollgeschosse hängt vom Baugebiet ab. Hier sind einige Beispiele:
#
# - **GE2**: 2 Vollgeschosse
# - **WA**: 1 bis 2 Vollgeschosse
# - **MI**: 1 bis 2 Vollgeschosse
# - **WR**: 1 Vollgeschoss
#
# Ja, zwei Vollgeschosse sind in den Baugebieten GE2, WA (teilweise) und MI zulässig.
#
# Referenz: Planzeichnung und Textliche Festsetzungen, Kapitel 1.1.3
#
# ### Welche Bauweisen sind festgesetzt?
#
# Die festgesetzten Bauweisen sind:
#
# - **Offene Bauweise**: Nur Einzel- und Doppelhäuser zulässig
# - **Geschlossene Bauweise**
#
# Referenz: Zeichenerklärung und Textliche Festsetzungen, Kapitel 1.2
#
# ### Werden die seitlichen Abstandsflächen eingehalten?
#
# Das ist mir nicht bekannt. Die Informationen über die Einhaltung der seitlichen Abstandsflächen sind nicht in den vorliegenden Daten enthalten.
#
# ### Welche Bauweise ist für Wohngebäude zulässig?
#
# Für Wohngebäude ist in den meisten Fällen die **offene Bauweise** zulässig, was bedeutet, dass nur Einzel- und Doppelhäuser erlaubt sind.
#
# Referenz: Zeichenerklärung und Textliche Festsetzungen, Kapitel 1.2
# #############################################
# ### Welche Gebäudearten sind erlaubt?
# Die erlaubten Gebäudearten hängen von der Art der Baugebiete ab. Es gibt verschiedene Baugebiete wie reines Wohngebiet (WR), allgemeines Wohngebiet (WA), Mischgebiet (MI) und eingeschränktes Gewerbegebiet (GE2). Die spezifischen Gebäudearten sind in den jeweiligen Baugebieten festgelegt.
#
# ### Ist ein Wohnhaus erlaubt?
# Ja, ein Wohnhaus ist in den Baugebieten "WR" (reines Wohngebiet) und "WA" (allgemeines Wohngebiet) erlaubt. (Kapitel 1.1.1)
#
# ### Welche GRZ und GFZ sind festgesetzt?
# Die Grundflächenzahl (GRZ) und Geschossflächenzahl (GFZ) variieren je nach Baugebiet. Hier sind einige Beispiele:
#
# - **GE2**: GRZ 0,6, GFZ 1,2
# - **WA**: GRZ 0,3 bis 0,5, GFZ 0,4 bis 0,8
# - **MI**: GRZ 0,4, GFZ 0,5
# - **WR**: GRZ 0,3 bis 0,5, GFZ 0,5 (Kapitel 1.1.1)
#
# ### Liegen die Werte GRZ von 0,17 und ein GFZ von 0.35 unter den maximal erlaubten Werten?
# Ja, die Werte GRZ von 0,17 und GFZ von 0.35 liegen unter den maximal erlaubten Werten in den genannten Baugebieten. (Kapitel 1.1.1)
#
# ### Wieviel Vollgeschosse sind erlaubt?
# Die Anzahl der erlaubten Vollgeschosse variiert je nach Baugebiet:
#
# - **GE2**: II Vollgeschosse
# - **WA**: I bis II Vollgeschosse
# - **MI**: I bis II Vollgeschosse
# - **WR**: I Vollgeschoss (Kapitel 1.1.3)
#
# ### Sind zwei Vollgeschosse zulässig?
# Ja, in den Baugebieten "GE2", "WA" (teilweise) und "MI" sind zwei Vollgeschosse zulässig. (Kapitel 1.1.3)
#
# ### Welche Bauweisen sind festgesetzt?
# Die festgesetzten Bauweisen sind:
#
# - **Offene Bauweise**: Nur Einzel- und Doppelhäuser zulässig
# - **Geschlossene Bauweise** (Kapitel 1.2)
#
# ### Werden die seitlichen Abstandsfläche eingehalten?
# Das ist mir nicht bekannt. Die Informationen über die Einhaltung der seitlichen Abstandsflächen sind nicht in den vorliegenden Daten enthalten.
#
# ### Welche Bauweise ist für Wohngebäude zulässig?
# Für Wohngebäude ist die "offene Bauweise" zulässig, in der nur Einzel- und Doppelhäuser erlaubt sind. (Kapitel 1.2)
# #############################################
# ### Welche Gebäudearten sind erlaubt?
# Die erlaubten Gebäudearten sind abhängig vom Baugebiet:
# - **WR**: Reines Wohngebiet (§ 3 BauNVO)
# - **WA**: Allgemeines Wohngebiet (§ 4 BauNVO)
# - **MI**: Mischgebiet (§ 6 BauNVO)
# - **GE2**: Eingeschränktes Gewerbegebiet für nicht wesentlich störende Gewerbebetriebe (§ 8 BauNVO)
#
# (Referenz: Zeichenerklärung, Art der baulichen Nutzung)
#
# ### Ist ein Wohnhaus erlaubt?
# Ja, ein Wohnhaus ist in den Baugebieten **WR** (Reines Wohngebiet) und **WA** (Allgemeines Wohngebiet) erlaubt.
#
# (Referenz: Zeichenerklärung, Art der baulichen Nutzung)
#
# ### Welche GRZ und GFZ sind festgesetzt?
# Die festgesetzten Werte für GRZ (Grundflächenzahl) und GFZ (Geschossflächenzahl) variieren je nach Baugebiet:
# - **GE2**: GRZ 0,6, GFZ 1,2
# - **WA**: GRZ 0,3 bis 0,5, GFZ 0,4 bis 0,8
# - **MI**: GRZ 0,4, GFZ 0,5
# - **WR**: GRZ 0,3 bis 0,5, GFZ 0,5
#
# (Referenz: Planzeichnung)
#
# ### Liegen die Werte GRZ von 0,17 und ein GFZ von 0.35 unter den maximal erlaubten Werten?
# Ja, die Werte GRZ von 0,17 und GFZ von 0,35 liegen unter den maximal erlaubten Werten in allen genannten Baugebieten.
#
# (Referenz: Planzeichnung)
#
# ### Wieviel Vollgeschosse sind erlaubt?
# Die Anzahl der erlaubten Vollgeschosse variiert je nach Baugebiet:
# - **GE2**: II Vollgeschosse
# - **WA**: I oder II Vollgeschosse
# - **MI**: I oder II Vollgeschosse
# - **WR**: I Vollgeschoss
#
# (Referenz: Planzeichnung)
#
# ### Sind zwei Vollgeschosse zulässig?
# Ja, zwei Vollgeschosse sind in den Baugebieten **GE2**, **WA** (teilweise), und **MI** zulässig.
#
# (Referenz: Planzeichnung)
#
# ### Welche Bauweisen sind festgesetzt?
# Die festgesetzten Bauweisen sind:
# - **Offene Bauweise**: Nur Einzel- und Doppelhäuser zulässig
# - **Geschlossene Bauweise**
#
# (Referenz: Zeichenerklärung, Bauweise)
#
# ### Werden die seitlichen Abstandsfläche eingehalten?
# Das ist mir nicht bekannt.
#
# ### Welche Bauweise ist für Wohngebäude zulässig?
# Für Wohngebäude ist die **offene Bauweise** zulässig, in der nur Einzel- und Doppelhäuser erlaubt sind.
#
# (Referenz: Zeichenerklärung, Bauweise)
# #############################################

# %%
# Quellen
pprint([msg211_l04_nz, msg211_l04_ze, msg221_l04_nz, msg231_l04_tt])
# Out:
# Hier ist das Schema der Tabellenerklärung in ASCII-Tabellenform:
#
# ```
# +---------------------+--------------------------+
# | Baugebiet           | Zahl der Vollgeschosse   |
# +---------------------+--------------------------+
# | Grundflächenzahl    | Geschossflächenzahl      |
# +---------------------+--------------------------+
# | -                   | Bauweise                 |
# +---------------------+--------------------------+
# | Dachform und Dachneigung                       |
# +-----------------------------------------------+
# ```
# #############################################
# ### Art der baulichen Nutzung
#
# - **Wohnbauflächen**
#   - **WR**: Reines Wohngebiet (§ 3 BauNVO)
#   - **WA**: Allgemeines Wohngebiet (§ 4 BauNVO)
# - **Gemischte Bauflächen**
#   - **MI**: Mischgebiet (§ 6 BauNVO)
#   - **GE2**: Eingeschränktes Gewerbegebiet für nicht wesentlich störende Gewerbebetriebe (§ 8 BauNVO)
#
# ### Maß der baulichen Nutzung
#
# - **Zahl der Vollgeschosse** (§ 18 BauNVO)
# - **Grundflächenzahl (GRZ)** (§ 19 BauNVO)
# - **Geschossflächenzahl (GFZ)** (§ 20 BauNVO)
#
# ### Bauweise
#
# - **Offene Bauweise**: Nur Einzel- und Doppelhäuser zulässig
# - **Geschlossene Bauweise**
#
# ### Überbaubare Grundstücksfläche
#
# - **Baugrenze** (§ 23 (3) BauNVO)
# #############################################
# Hier sind die Werte der jeweiligen Nutzungsschablonen im JSON-Format:
#
# ```json
# [
#   {
#     "Baugebiet": "GE 2",
#     "Zahl der Vollgeschosse": "II",
#     "Grundflächenzahl": "0,6",
#     "Geschossflächenzahl": "1,2",
#     "Bauweise": "0",
#     "Dachform und Dachneigung": "SD DN 12-18°"
#   },
#   {
#     "Baugebiet": "WA",
#     "Zahl der Vollgeschosse": "I",
#     "Grundflächenzahl": "0,3",
#     "Geschossflächenzahl": "0,5",
#     "Bauweise": "0",
#     "Dachform und Dachneigung": "SD DN 28-33°"
#   },
#   {
#     "Baugebiet": "WA",
#     "Zahl der Vollgeschosse": "I",
#     "Grundflächenzahl": "0,3",
#     "Geschossflächenzahl": "0,5",
#     "Bauweise": "0",
#     "Dachform und Dachneigung": "SD DN 28-33°"
#   },
#   {
#     "Baugebiet": "WA",
#     "Zahl der Vollgeschosse": "I",
#     "Grundflächenzahl": "0,3",
#     "Geschossflächenzahl": "0,5",
#     "Bauweise": "0",
#     "Dachform und Dachneigung": "SD DN 28-33°"
#   },
#   {
#     "Baugebiet": "MI",
#     "Zahl der Vollgeschosse": "II",
#     "Grundflächenzahl": "0,4",
#     "Geschossflächenzahl": "0,5",
#     "Bauweise": "0",
#     "Dachform und Dachneigung": "SD DN 28-33°"
#   },
#   {
#     "Baugebiet": "WR",
#     "Zahl der Vollgeschosse": "I",
#     "Grundflächenzahl": "0,5",
#     "Geschossflächenzahl": "-",
#     "Bauweise": "g",
#     "Dachform und Dachneigung": "FD"
#   },
#   {
#     "Baugebiet": "WA",
#     "Zahl der Vollgeschosse": "I",
#     "Grundflächenzahl": "0,3",
#     "Geschossflächenzahl": "0,5",
#     "Bauweise": "0",
#     "Dachform und Dachneigung": "SD DN 28-33°"
#   },
#   {
#     "Baugebiet": "WA",
#     "Zahl der Vollgeschosse": "I",
#     "Grundflächenzahl": "0,5",
#     "Geschossflächenzahl": "-",
#     "Bauweise": "0",
#     "Dachform und Dachneigung": "FD"
#   },
#   {
#     "Baugebiet": "WR",
#     "Zahl der Vollgeschosse": "I",
#     "Grundflächenzahl": "0,3",
#     "Geschossflächenzahl": "0,5",
#     "Bauweise": "0",
#     "Dachform und Dachneigung": "SD-DN 28-33°"
#   },
#   {
#     "Baugebiet": "WA",
#     "Zahl der Vollgeschosse": "I",
#     "Grundflächenzahl": "0,3",
#     "Geschossflächenzahl": "0,5",
#     "Bauweise": "0",
#     "Dachform und Dachneigung": "SD-DN 28-33°"
#   },
#   {
#     "Baugebiet": "WA",
#     "Zahl der Vollgeschosse": "I",
#     "Grundflächenzahl": "0,5",
#     "Geschossflächenzahl": "-",
#     "Bauweise": "g",
#     "Dachform und Dachneigung": "FD"
#   },
#   {
#     "Baugebiet": "WA",
#     "Zahl der Vollgeschosse": "I",
#     "Grundflächenzahl": "0,3",
#     "Geschossflächenzahl": "0,5",
#     "Bauweise": "0",
#     "Dachform und Dachneigung": "SD-DN 28-33°"
#   },
#   {
#     "Baugebiet": "MI",
#     "Zahl der Vollgeschosse": "I",
#     "Grundflächenzahl": "0,4",
#     "Geschossflächenzahl": "0,5",
#     "Bauweise": "0",
#     "Dachform und Dachneigung": "SD-DN 28-33°"
#   },
#   {
#     "Baugebiet": "WA",
#     "Zahl der Vollgeschosse": "II",
#     "Grundflächenzahl": "0,4",
#     "Geschossflächenzahl": "0,8",
#     "Bauweise": "0",
#     "Dachform und Dachneigung": "SD-DN 28-33°"
#   },
#   {
#     "Baugebiet": "WA",
#     "Zahl der Vollgeschosse": "I",
#     "Grundflächenzahl": "0,3",
#     "Geschossflächenzahl": "0,4",
#     "Bauweise": "0",
#     "Dachform und Dachneigung": "SD-DN 28-33°"
#   }
# ]
# ```
# #############################################
# ['### Planungsrechtliche Festsetzungen (§ 9 (1) BBauG u. BauNVO)
#
# #### 1.1 Bauliche Nutzung
#
# **1.1.1 Art und Maß der baulichen Nutzung (§§ 16 - 21 BauNVO)**
# - Teilweise ist, wenn es vom Gelände und den Festsetzungen her möglich ist, ein weiteres Geschoss als anrechenbares Vollgeschoss zulässig.
#
# **1.1.2 Ausnahmen im Sinne des § 3 (3) BauNVO**
# - Gemäß § 1 (4) BauNVO nicht Bestandteil des Bebauungsplanes und daher nicht zulässig.
#
# **1.1.3 Zahl der Vollgeschosse**
# - Entsprechend den Einzeichnungen im Plan (§ 18 BauNVO und § 2 (4) LBO).
#
# #### 1.2 Bauweise
# - § 22 BauNVO, siehe Einzeichnungen im Plan.
#
# #### 1.3 Stellung der Gebäude (§ 9 (1) 1 b BBauG)
# - Firstrichtung wie im Plan eingezeichnet.
#
# #### 1.4 Nebenanlagen im Sinne des § 14 BauNVO
# - In den nicht überbaubaren Grundstücksflächen nicht zugelassen.
# - Garagen sind im Haus oder an den dafür ausgewiesenen Stellen mit einem Dach zu erstellen.
# - Freistehende Einzelgaragen sind nur in Verbindung mit einer Sichtschutzwand, einem gedeckten Einstellplatz oder einer sonstigen baulichen Einbindung in die Gesamtanlage zulässig.
#
# #### 1.5 Höhenlage der Gebäude
# - Die Höhenlagen der Gebäude sind im Beilageplan festgelegt.
#
# #### 1.6 Freizuhaltende Sichtfelder (§ 9 (1) 14 BBauG)
# - Die im Bebauungsplan eingezeichneten Sichtfelder sind zur Erhaltung einer freien Verkehrsübersicht von jeglicher Einfriedung und Bepflanzung über 0,8 m Höhe, auf die Verkehrfläche bezogen, freizuhalten.']
# #############################################
