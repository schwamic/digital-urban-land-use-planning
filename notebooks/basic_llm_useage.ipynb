# %% [markdown]
# # LeoML

# %%
from transformers import pipeline, AutoConfig, AutoTokenizer, AutoModelForCausalLM

# jphme/em_german_7b_v01
# jphme/em_german_7b_leo
#config = AutoConfig.from_pretrained(model_name)
#llm = AutoModelForCausalLM.from_config(config)

# a) Use a pipeline as a high-level helper
generator = pipeline("text-generation", model="LeoLM/leo-mistral-hessianai-7b")
generator("Schreibe einen Satz für eine Begrüßung in einem Brief an einen Freund.")

# a) Use a pipeline as a high-level helper
question_answerer = pipeline("question-answering", model="deepset/gelectra-base-germanquad")
question_answerer(
    question="Wo arbeitet Michael do?",
    context="Tobi arbeitet bei der Rocket-Factory in Augsburg. Heute hat Michael seinen ersten in seiner neuen Firma. Tobi arbeitet unterstützt in als Mentor in der Einarbeitungsphase.",
)

# b) Load model directly
#tokenizer = AutoTokenizer.from_pretrained(model_name)
#model = AutoModelForCausalLM.from_pretrained(model_name)

# llm=AutoModelForCausalLM.from_pretrained(
#     pretrained_model_name_or_path=model_name, 
#     #low_cpu_mem_usage=False, 
#     offload_folder="offload",
#     #load_in_8bit=True
# )
#tokenizer=AutoTokenizer.from_pretrained(model_name)
#tokenizer.pad_token_id=tokenizer.eos_token_id

# generation_config=GenerationConfig(
#     max_new_tokens=500,
#     temperature=0.4,
#     top_p=0.95,
#     top_k=40,
#     repetition_penalty=1.2,
#     bos_token_id=tokenizer.bos_token_id,
#     eos_token_id=tokenizer.eos_token_id,
#     do_sample=True,
#     use_cache=True,
#     output_attentions=False,
#     output_hidden_states=False,
#     output_scores=False,
#     remove_invalid_values=True
# )

# streamer = TextStreamer(tokenizer)

# LeoLM/leo-mistral-hessianai-7b
# llm = AutoModelForCausalLM.from_pretrained(
#     pretrained_model_name_or_path="LeoLM/leo-mistral-hessianai-7b",
#     device_map="auto",
#     torch_dtype=torch.bfloat16,
#     offload_folder="offload",
#     # use_flash_attn_2=True,  # optional
# )
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:32<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 10
#       5 model_name='LeoLM/leo-mistral-hessianai-7b'
#       6 #config = AutoConfig.from_pretrained(model_name)
#       7 #llm = AutoModelForCausalLM.from_config(config)
#       8
#       9 # a) Use a pipeline as a high-level helper
# ---> 10 pipe = pipeline("text-generation", model=model_name)
#      12 # b) Load model directly
#      13 tokenizer = AutoTokenizer.from_pretrained(model_name)
#
# File /opt/anaconda3/envs/masterarbeit_stage_1/lib/python3.11/site-packages/transformers/pipelines/__init__.py:870, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, framework, revision, use_fast, token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
# ...

# %%
def ask_model(instruction, system='Du bist ein hilfreicher Assistent.'):
    prompt=f"{system} USER: {instruction} ASSISTANT:"
    input_tokens=tokenizer(prompt, return_tensors="pt").to(model.device)
    output_tokens=model.generate(**input_tokens,  generation_config=generation_config, streamer=streamer)[0]
    answer=tokenizer.decode(output_tokens, skip_special_tokens=True)
    return answer

# %%
prompt = "Schreibe einen Satz zum Theme Baurecht in Bayern."
answer=ask_model(prompt)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 2
#       1 prompt = "Schreibe einen Satz zum Theme Baurecht in Bayern."
# ----> 2 print(llm(prompt))
#
# File /opt/anaconda3/envs/masterarbeit_stage_1/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/envs/masterarbeit_stage_1/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
# ...
