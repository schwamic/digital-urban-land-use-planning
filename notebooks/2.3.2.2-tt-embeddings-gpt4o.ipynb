# %% [markdown]
# # 2.3.2.2 Textlicher Teil Bebauungsplan – Embeddings + Vector Store (GPT-4o)
#
# Das Context-Window (128.000 Tokens) in GPT-4o ist begrenzt. Entsprechend muss ab einer gewissen Seitenanzahl des schriftlichen Dokuments eines Bebauungsplans auf Emebddings zurückgegriffen werden. (~765 Tokens pro Bild mit hoher Auflösung / 85 Tokens pro Bild mit niedriger Auflösung)
#
# * Zero-Shot
# * Chain-Of-Thought

# %%
import asyncio
import os
from dotenv import load_dotenv, find_dotenv
from dotmap import DotMap
from langchain_openai import OpenAIEmbeddings
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_chroma import Chroma
from utils.parser import Parser
from utils.openai import OpenAI
from utils.runner import Runner
from utils.pprint import pprint

instructions =  "Du bist ein Assistent zur getreuen Wiedergabe von Textinformationen aus Dokumenten. Achte auf Vollständigkeit."
ava = OpenAI(instructions)
parser = Parser()
runner = Runner()

load_dotenv(find_dotenv())
embeddings_model = OpenAIEmbeddings(
    api_key=os.getenv("OPENAI_API_KEY"),
    model="text-embedding-3-large",
)

# %%
# A) OCR via RapidOCR --> CNN/RNN != Transformer (LLM)
# from langchain_community.document_loaders import PyMuPDFLoader
# pdf_path = "../data/raw/bpläne/2_zeichnung_textteil_getrennt/F 11- 02 Gewerbegebiet Himmelreich - schriftlicher Teil.pdf"
# loader = PyMuPDFLoader(pdf_path, extract_images=True)
# data = loader.load()
# print(data[0])

# %%
# B1) OCR via GPT-4o / Kompletter schriftlicher Teil
# Idee: Jede Seite einzeln verarbeiten, um den Fokus zu maximieren und Context-Window klein zu halten.
async def page2text(page_prompt):
    msg = ava.request([
        {
            "type": "text",
            "text": 'Extrahiere den kompletten Textinhalt. Output im LaTeX-Format.'
        },
        page_prompt
    ])
    return msg

pdf_path = "../data/raw/bpläne/2_zeichnung_textteil_getrennt/F11-01-TT.pdf"
prompts = parser.pdf2prompts(pdf_path)
prompt_chain = list(map(lambda prompt: page2text(prompt), prompts))
data_list = await asyncio.gather(*prompt_chain)
pprint(data_list)
# Out:
# ```latex
# \documentclass{article}
# \usepackage[utf8]{inputenc}
#
# \begin{document}
#
# \section*{SCHRIFTLICHER TEIL (Teil B)}
#
# \subsection*{BEBBAUUNGSPLAN "GEWERBEGEBIET HIMMELREICH"}
#
# \subsubsection*{STADT LAICHINGEN, GEMARKUNG FELDSTETTEN, ALB-DONAU-KREIS}
#
# Der Geltungsbereich wird durch das Planzeichen im Lageplan begrenzt.
#
# Lageplan M 1: 500
#
# Für die planungsrechtlichen bzw. bauordnungsrechtlichen Festsetzungen gelten:
#
# \begin{itemize}
#     \item \textbf{Baugesetzbuch (BauGB)}\\
#     in der Fassung der Bekanntmachung vom 27.08.1997 (BGBl. I. S. 2141).
#
#     \item \textbf{Baunutzungsverordnung (BauNVO)}\\
#     in der Fassung der Bekanntmachung vom 23.01.1990 (BGBl. S. 132), zuletzt geändert am 22.04.1993 (BGBl. I. S. 466).
#
#     \item \textbf{Planzeichenverordnung 1990 (PlanZV 90)}\\
#     in der Fassung der Bekanntmachung vom 18.12.1990 (BGBl. I. S. 58).
#
#     \item \textbf{Landesbauordnung (LBO)}\\
#     in der Fassung der Bekanntmachung vom 08.08.1995 (GBl. S. 617).
# \end{itemize}
#
# \subsubsection*{Bisherige Festsetzungen:}
# Mit in Kraft treten dieses Bebauungsplanes treten im Geltungsbereich alle bisherigen gemeindlichen bauplanungsrechtlichen und bauordnungsrechtlichen Festsetzungen außer Kraft.
#
# \end{document}
# ```
# #############################################
# ```latex
# \documentclass{article}
# \usepackage[utf8]{inputenc}
# \usepackage{geometry}
# \geometry{a4paper, margin=1in}
#
# \begin{document}
#
# \section*{Schriftlicher Teil Bebauungsplan "Gewerbegebiet Himmelreich"\\
# Stadt Laichingen, Gemarkung Feldstetten, Alb-Donau-Kreis, 19.08.2000}
#
#
# oindent
# In Ergänzung der Planzeichnung wird folgendes festgesetzt:
#
# \begin{enumerate}
#     \item \textbf{Planungsrechtliche Festsetzungen (§ 9 (1) und (2) BauGB und BauNVO)}
#     \begin{enumerate}
#         \item \textbf{Art der baulichen Nutzung (§§ 1 - 15 BauNVO)}
#         \begin{enumerate}
#             \item \textbf{Eingeschränktes Gewerbegebiet (GEE) (§ 8 BauNVO i.V.m. § 1 (4) BauNVO)}
#             \begin{enumerate}
#                 \item \textbf{Zulässig sind / zulässig ist:}
#                 \begin{enumerate}
#                     \item \textbf{Gewerbebetriebe, die das Wohnen nicht wesentlich stören,}\\
#                     wobei bei Einzelhandelsbetrieben (gem. § 1 (5) BauNVO i.V.m. § 1 (9) BauNVO) nur die nicht innenstadtrelevanten Sortimente Kfz, Motorräder, Mopeds, Fahrräder, Kfz-Zubehör, Rasenmäher, Landmaschinen, Fahrrad- und Motorradzubehör, Brennstoffe und Mineralölerzeugnisse zulässig sind.
#                     \item Der Verkauf von auf dem Grundstück produzierten Waren auf einer untergeordneten Fläche ist zulässig.
#                 \end{enumerate}
#                 \item \textbf{Nicht zulässig sind / nicht zulässig ist:}
#                 \begin{enumerate}
#                     \item Nutzungen gemäß § 8 (3) Nr. 3 BauNVO (Vergnügungsstätten) sind gemäß § 1 (6) BauNVO nicht Bestandteil des Bebauungsplans und damit nicht zulässig.
#                     \item Einzelhandelsbetriebe mit innenstadtrelevanten und bestimmten nicht innenstadtrelevanten Sortimenten sind gemäß § 1 (5) BauNVO i.V.m. § 1 (9) BauNVO nicht zulässig.
#                 \end{enumerate}
#             \end{enumerate}
#             \item \textbf{Gewerbegebiet (GE) (§ 8 BauNVO)}
#             \begin{enumerate}
#                 \item \textbf{Zulässig sind / zulässig ist:}
#                 \begin{enumerate}
#                     \item \textbf{Gewerbebetriebe aller Art,}\\
#                     wobei bei Einzelhandelsbetrieben (gem. § 1 (5) BauNVO i.V.m. § 1 (9) BauNVO) nur die nicht innenstadtrelevanten Sortimente Kfz, Motorräder, Mopeds, Fahrräder, Kfz-Zubehör, Rasenmäher, Landmaschinen, Fahrrad- und Motorradzubehör, Brennstoffe und Mineralölerzeugnisse zulässig sind.
#                     \item Der Verkauf von auf dem Grundstück produzierten Waren auf einer untergeordneten Fläche ist zulässig.
#                 \end{enumerate}
#                 \item \textbf{Nicht zulässig sind / nicht zulässig ist:}
#                 \begin{enumerate}
#                     \item Nutzungen gemäß § 8 (3) Nr. 3 BauNVO (Vergnügungsstätten) sind gemäß § 1 (6) BauNVO nicht Bestandteil des Bebauungsplans und damit nicht zulässig.
#                     \item Einzelhandelsbetriebe mit innenstadtrelevanten und bestimmten nicht innenstadtrelevanten Sortimenten sind gemäß § 1 (5) BauNVO i.V.m. § 1 (9) BauNVO nicht zulässig.
#                 \end{enumerate}
#             \end{enumerate}
#         \end{enumerate}
#     \end{enumerate}
# \end{enumerate}
#
# \end{document}
# ```
# #############################################
# ```latex
# \documentclass{article}
# \usepackage[utf8]{inputenc}
# \usepackage{geometry}
# \geometry{a4paper, margin=1in}
#
# \begin{document}
#
# \section*{Schriftlicher Teil Bebauungsplan "Gewerbegebiet Himmelreich"\\
# Stadt Laichingen, Gemarkung Feldstetten, Alb-Donau-Kreis, 19.06.2000}
#
# \subsection*{1.1.3 Innenstadtrelevante Sortimente gemäß 1.1.1.2.2 und 1.1.2.2.2 sind:}
# \begin{itemize}
#     \item Nahrungs- und Genussmittel einschließlich der Betriebe des Ernährungshandwerks
#     \item Drogeriewaren, Parfümeriewaren
#     \item Apothekenwaren
#     \item Blumen, zoologischer Bedarf
#     \item Oberbekleidung, Kürschnerwaren, sonstige Textilwaren, Wolle, Kurzwaren, Sportbekleidung
#     \item Schuhe, Lederwaren
#     \item Haushaltswaren, Unterhaltungselektronik, optische und feinmechanische Geräte, Foto- und Schreibwaren, Bücher, Spielwaren
#     \item Uhren, Schmuck, Silberwaren
#     \item Musikalien, Ton- und Bildträger
#     \item Heimtextilien, Bettwaren, Gardinen und Zubehör
# \end{itemize}
#
# \subsection*{1.1.4 Bestimmte nicht innenstadtrelevante Sortimente gemäß 1.1.1.2.2 und 1.1.2.2.2 sind:}
# \begin{itemize}
#     \item Möbel, Kücheneinrichtungen, Elektrogeräte (weiße Ware), Öfen, Herde, Elektroeinbaugeräte, Haushaltstechnik
#     \item Büromöbel, Büromaschinen, Computer, Büroorganisationsmittel, Büro- und Kommunikationstechnik (vorwiegender Absatz an gewerbliche Verwendung)
#     \item Holz, Bauelemente z.B. Fenster und Türen, Baustoffe, Sanitär / Fliesen, Installationsmaterial, Badeinrichtungen und -ausstattung, Eisenwaren und Werkzeuge, Maschinen und -zubehör
#     \item Beleuchtungskörper, Leuchten, Elektroinstallationsbedarf
#     \item Teppiche, Bodenbeläge, Farben, Lacke, Tapeten, Malereibedarf
#     \item Pflanzen, Pflege- und Düngemittel, Torf, Erde, Pflanzengefäße, Gartenwerkzeuge und -maschinen, Gartenmöbel, Gartenhäuser, Gewächshäuser u.a.
# \end{itemize}
#
# \subsection*{1.1.5 Randsortimente}
# Innenstadtrelevante, branchentypische Randsortimente sind in den zulässigen Verkaufsflächen gemäß 1.1.1.1.1 und 1.1.2.1.1 bis zu einer maximalen Fläche von 10\% der zulässigen Verkaufsfläche ausnahmsweise zulässig.
#
# \subsection*{1.1.6 Verkaufsfläche}
# Verkaufsfläche gemäß 1.1.1.5 ist die gesamte, dem Kunden zugängliche Fläche einschließlich Vorkassenzone und Verkaufsfläche im Freien mit Ausnahme der Kundensozialräume (WC und ähnliches).
#
# \section*{1.2 Maß der baulichen Nutzung (§ 16 - 21 a BauNVO)}
#
# \subsection*{1.2.1 Grundflächenzahl (§ 19 BauNVO)}
# - siehe Einträge im Lageplan -
#
# \subsection*{1.2.2 Geschossflächenzahl (§ 20 BauNVO)}
# - siehe Einträge im Lageplan -
#
# \subsection*{1.2.3 Höhe der baulichen Anlagen (§ 18 BauNVO)}
# - siehe Einträge im Lageplan -
# Die Gebäudehöhe wird gemessen von der Erdgeschossfußbodenhöhe (EFH) bis zur Schnittkante zwischen Außenwand und Dachhaut bzw. bis zur Oberkante Firstziegel.
#
# \end{document}
# ```
# #############################################
# Hier ist der extrahierte Textinhalt im LaTeX-Format:
#
# ```latex
# \documentclass{article}
# \usepackage[utf8]{inputenc}
# \usepackage{geometry}
# \geometry{a4paper, margin=1in}
#
# \begin{document}
#
# \section*{Schriftlicher Teil Bebauungsplan "Gewerbegebiet Himmelreich"\\
# Stadt Laichingen, Gemarkung Feldstetten, Alb-Donau-Kreis, 19.06.2000}
#
# \subsection*{1.3 Bauweise (§ 22 BauNVO)}
# - siehe Einschnitte im Lageplan -\\
# a = abweichende Bauweise. Es gilt die offene Bauweise, jedoch sind die Gebäudelängen nicht begrenzt.
#
# \subsection*{1.4 Überbaubare Grundstücksfläche (§ 9 (1) 2 BauGB)}
# Die überbaubare Grundstücksfläche wird durch die Festsetzung von Baugrenzen in der Planzeichnung bestimmt.\\
# Garagen im Sinne von § 12 BauNVO und Nebenanlagen im Sinne des § 14 BauNVO sowie Anlagen der Fremdenwerbung und bauliche Anlagen, die nach Landesrecht in den Abstandsflächen zulässig sind oder zugelassen werden können, sind nur innerhalb der überbaubaren Grundstücksflächen zulässig.
#
# \subsection*{1.5 Von der Bebauung freizuhaltende Flächen und Sichtfelder (§ 9 (1) 10 BauGB)}
# - siehe Einschnitte im Lageplan -\\
# Auf den, zugunsten von EVS und der Stadt (Leitungsrecht 1 und 2) sowie entlang der B 28 festgesetzten, von der Bebauung freizuhaltenden Grundstücksflächen, sind Garagen im Sinne von § 12 BauNVO und Nebenanlagen im Sinne von § 14 BauNVO unzulässig.\\
# Die im Lageplan ausgewiesenen Sichtfelder im Bereich der Straßeneinmündungen sind von Bäumen und Sträuchern sowie weiteren Anlagen über 0,70 m Höhe, gemessen von der Fahrbahnboberkante, freizuhalten bzw. freizumachen.
#
# \subsection*{1.6 Flächen und Maßnahmen zum Schutz, zur Pflege und zur Entwicklung von Boden, Natur und Landschaft (§ 9 (1) 20 BauGB)}
# \textbf{Maßnahme 1: Halbtrockenrasen}\\
# Die gekennzeichneten Hangbereiche sind durch geeignete Maßnahmen in nächstforhame, teilweise gebölsierte Halbtrockenrasen zurückzuverwandeln.\\
# Dazu sind die Hybridpappeln zu fällen und auf ca. 50\% der Fläche ist der Gehölzaufwuchs zu roden. Ablagerungen sind zu entfernen und über einen Zeitraum von 5 Jahren sind die Flächen 1-mal jährlich zu mähen einschließlich Abfuhr des Mähguts.
#
# \textbf{Maßnahme 2: Gewässer- und Bodenschutz}\\
# Die Stellplatzflächen sind mit wasserdurchlässigen Materialien wie Rasenpflaster, offenporigem Pflaster, Schotterrasen o. ä. zu befestigen, sofern dort keine Umlade- bzw. Wartungsarbeiten stattfinden.
#
# \subsection*{1.7 Leitungsrechte (§ 9 (1) 13 und 21 BauGB)}
# - siehe Einschnitte im Lageplan -\\
# LR 1: Leitungsrecht zugunsten der EnBW betr. Herstellung und Wartung von elektrischen Leitungen.\\
# LR 2: Leitungsrecht zugunsten der Stadt Laichingen betr. Herstellung und Wartung einer Wasserleitung DN 150.
#
# \end{document}
# ```
# #############################################
# Hier ist der extrahierte Textinhalt im LaTeX-Format:
#
# ```latex
# \documentclass{article}
# \usepackage[utf8]{inputenc}
# \usepackage{geometry}
# \geometry{a4paper, margin=1in}
#
# \begin{document}
#
# \section*{1.8 Flächen für das Anpflanzen von Bäumen, Sträuchern und sonstigen Bepflanzungen (§ 9 (1) 25a BauGB)}
#
# \subsection*{Pflanzgebot 1 Straßenbäume entlang der B 28}
# Entlang der B 28 sind hochstämmige Bergahorn (Acer pseudoplatanus) mit mindestens 20/25 cm Stammumfang zu pflanzen und dauerhaft zu erhalten. Die im Grünordnungsplan bzw. Bebauungsplan vorgegebenen Standorte dienen als Anhaltspunkt. Eine Abweichung um bis zu 2,00 m ist zulässig. Die Flächen unter den Bäumen sind als extensive Wiesenfläche anzusäen und zu unterhalten.
#
# \subsection*{Pflanzgebot 2 Straßenbäume im Wendehammer}
# Im Wendebereich der Straße "B" sind 3 hochstämmige Bergahorn (Acer pseudoplatanus) mit mindestens 20/25 cm Stammumfang zu pflanzen und dauerhaft zu erhalten.
#
# \subsection*{Pflanzgebot 3 Obstbäume}
# Am Fuß des Trockenhangs sind ortstypische Hochstamm-Apfelbäume zu pflanzen und dauerhaft zu erhalten. Die im Grünordnungsplan bzw. im Bebauungsplan vorgegebenen Standorte dienen als Anhaltspunkt. Eine Abweichung um bis zu 2,00 m ist zulässig. Die Flächen unter den Bäumen ist als extensive Wiesenfläche anzusäen und zu unterhalten.
#
# \subsection*{Pflanzgebot 4 Gehölzrieg el zur Landschaft}
# Innerhalb der gekennzeichneten Fläche ist ein 2-3 reihiger Gehölzrieg el aus ausschließlich standorttypischen Bäumen und Sträuchern der Pflanzlisten 1 und 2 anzulegen und dauerhaft zu erhalten. Die Pflanzung muß mindestens 70 \% der Fläche einnehmen. Pro 100 laufende Meter Länge der Pflanzung müssen dabei mindestens 10 Bäume verwendet werden. Zaunanlagen sind in die Pflanzung zu integrieren und müssen mindestens 2 Meter Abstand zur Grenze aufweisen.
#
# \subsection*{Pflanzgebot 5 Schleheng ebüsch}
# Innerhalb der gekennzeichneten Flächen sind 1-2 reihige Gehölzrieg el aus ausschließlich standorttypischen Sträuchern der Pflanzliste 2 anzulegen und dauerhaft zu erhalten. 80 \% der Gehölze müssen dabei Schlehen (Prunus spinosa) sein.
#
# \subsection*{Pflanzgebot 6 Gehölze auf den Baugrundstücken}
# Innerhalb der gekennzeichneten Flächen sind einzelne Bäume und Strauchgruppen aus ausschließlich Gehölzen der Pflanzlisten 1 und 2 anzulegen und dauerhaft zu erhalten. Die restlichen Flächen sind als extensive Rasenflächen anzusäen. Die Gehölzgruppen müssen mindestens 20 \% der Vegetationsfläche einnehmen, pro 100 m laufender Meter Grenze müssen mindestens 3 Bäume gepflanzt werden. Ausgenommen sind alle Zugangs- und Zufahrtsbereiche zu den Grundstücken.
#
# \subsection*{Pflanzgebot 7 Bepflanzung der Stellplatzflächen}
# Zur Begrünung der Stellplätze ist pro 8 Plätze ein hochstämmiger Laubbaum mit mindestens 20/25 cm Stammumfang zu pflanzen und dauerhaft zu erhalten. Die Pflanzfläche muß mindestens 6,00 m² betragen. Befahrbare Abdeckungen der Baumscheiben (Baumroste) sind zulässig.
#
# \subsection*{Pflanzgebot 8 Gehölzrieg el zur Landschaft}
# Innerhalb der gekennzeichneten Fläche ist ein 2-3 reihiger Gehölzrieg el aus ausschließlich standorttypischen Sträuchern der Pflanzliste 2 anzulegen und dauerhaft zu erhalten. Die Pflanzung muß mindestens 70 \% der Fläche einnehmen. Zaunanlagen sind in die Bepflanzung zu integrieren und müssen mindestens 2 Meter Abstand zur Grenze aufweisen.
#
# \end{document}
# ```
# #############################################
# ```latex
# \documentclass{article}
# \usepackage[utf8]{inputenc}
# \usepackage{geometry}
# \geometry{a4paper, margin=1in}
#
# \begin{document}
#
# \section*{Schriftlicher Teil Bebauungsplan "Gewerbegebiet Himmelreich"\\
# Stadt Laichingen, Gemarkung Feldstetten, Alb-Donau-Kreis, 19.06.2000}
#
# \subsection*{Pflanzliste 1: Standortgerechte Bäume}
# \begin{itemize}
#     \item Feldahorn \hfill \textit{Acer campestre}
#     \item Bergahorn \hfill \textit{Acer pseudoplatanus}
#     \item Hainbuche \hfill \textit{Carpinus betulus}
#     \item Rotbuche \hfill \textit{Fagus sylvatica}
#     \item Vogelkirsche \hfill \textit{Prunus avium}
#     \item Weichselkirsche \hfill \textit{Prunus mahaleb}
#     \item Mehlbeere \hfill \textit{Sorbus aria}
#     \item Vogelbeere \hfill \textit{Sorbus aucuparia}
#     \item Speierling \hfill \textit{Sorbus domestica}
# \end{itemize}
#
# \subsection*{Pflanzliste 2: Standortgerechte Sträucher}
# \begin{itemize}
#     \item Felsenbirne \hfill \textit{Amelanchier ovalis}
#     \item Kornelkirsche \hfill \textit{Cornus mas}
#     \item Hartriegel \hfill \textit{Cornus sanguinea}
#     \item Haselnuss \hfill \textit{Corylus avellana}
#     \item Weißdorn \hfill \textit{Crataegus monogyna}
#     \item Pfaffenhütchen \hfill \textit{Euonymus europaeus}
#     \item Liguster \hfill \textit{Ligustrum vulgare}
#     \item Heckenkirsche \hfill \textit{Lonicera xylosteum}
#     \item Schlehe \hfill \textit{Prunus spinosa}
#     \item Kreuzdorn \hfill \textit{Rhamnus cathartica}
#     \item Hundsrose \hfill \textit{Rosa canina}
#     \item Purpurweide \hfill \textit{Salix purpurea}
#     \item Holunder \hfill \textit{Sambucus nigra}
#     \item Schneeball \hfill \textit{Viburnum lantana}
# \end{itemize}
#
# \subsection*{1.9 Flächen mit Bindungen für Bepflanzungen und für die Erhaltung von Bäumen, Sträuchern und sonstigen Bepflanzungen (§ 9 (1) 25b BauGB)}
# Das gekennzeichnete Ligustergebüsch ist zu erhalten. Die beiden Weiden innerhalb dieses Gebüsches sind jedoch zu entfernen und durch die Straßenbäume des Pflanzgebotes 1 zu ersetzen.
#
# \section*{2. Hinweise}
#
# \subsection*{2.1 Bodenschutz}
# Um die wertvolle Ressource Boden zu schonen, sind die Hinweise der Informationsschrift des Ministeriums für Ernährung, Landwirtschaft, Umwelt und Forsten Baden-Württemberg "Erhaltung fruchtbaren und kulturfähigen Bodens bei Flächeninanspruchnahmen" zu beachten.\\
# Bodenaushub hat möglichst im Baugebiet zu verbleiben und ist dort wiederzuverwenden (z.B. an Böschungen, Lärmschutzwällen).\\
# Mutterboden ist getrennt zwischenzulagern und für die Gestaltung der Außenanlagen einzusetzen. Überschüssiger Mutterboden muß auf Oberboden-deponien gebracht werden.\\
# Bei Auf- und Abtrag von Rohboden ist ein Massenausgleich anzustreben.\\
# Werden während der Aushubarbeiten außerhalb der altlastenverdächtigen Flächen Verunreinigungen des Bodens festgestellt (z.B. Müllrückstände, Verfärbungen des Bodens, Geruchsbelästigungen o.ä.), ist das Landratsamt Alb-Donau-Kreis, Tel. 0731/185-1561 oder 1562 sofort zu benachrichtigen.
#
# \end{document}
# ```
# #############################################
# ```latex
# \section{2.2 Archäologische Funde}
# Sollten im Zuge von Erdarbeiten archäologische Funde (z.B. Mauern, Gruben, Brandschichten) angeschnitten oder Funde gemacht werden (z.B. Scherben, Metallteile, Knochen), ist das Landesdenkmalamt, Abt. Archäologische Denkmalpflege, unverzüglich zu benachrichtigen. Auf § 20 DSchG wird verwiesen.
#
# \section{2.3 Grundwasserschutz}
# Das Plangebiet befindet sich in der Zone III A des fachtechnisch abgegrenzten Wasserschutzgebietes Blaubeuren.
#
# \section{2.4 Schallimmissionen}
# Das Baugebiet wird im Immissionsbereich der überörtlichen Straße, besonders im Schalleinwirkungsbereich, liegen. Es ist durch die überörtliche Straße vorbelastet. Der Straßenbaulastträger ist aus diesem Grund nicht verpflichtet, sich an den Kosten eventuell notwendig werdender Schutzmaßnahmen (z.B. Schallschutz) zu beteiligen.
#
# \begin{flushleft}
# Aufgestellt: Reutlingen, den 19.06.2000
# \end{flushleft}
#
# \begin{flushleft}
# \begin{tabbing}
# ...
# #############################################
# ```latex
# \documentclass{article}
# \usepackage[utf8]{inputenc}
#
# \begin{document}
#
# \section*{Bebauungsplan "Gewerbegebiet Himmelreich"}
#
# \subsection*{Verfahrensvermerke}
#
# \textbf{Stadt Laichingen, Gemarkung Feldstetten, Alb-Donau-Kreis}
#
# \begin{itemize}
#     \item \textbf{Aufstellungsbeschluss}
#     \begin{itemize}
#         \item Öffentliche Bekanntmachung: 09.11.1998
#         \item Öffentliche Bekanntmachung: 12.11.1998
#     \end{itemize}
#     \item \textbf{Bürgerbeteiligung}
#     \begin{itemize}
#         \item Informationsveranstaltung: 19.11.1998
#         \item Einsichtnahme / Erörterung: 20.11.1998 - 04.12.1998
#     \end{itemize}
#     \item \textbf{Beteiligung Träger öffentlicher Belange}
#     \begin{itemize}
#         \item 18.11.1998 - 18.12.1998
#     \end{itemize}
#     \item \textbf{Auslegungsbeschluss}
#     \begin{itemize}
#         \item Öffentliche Bekanntmachung: 18.01.1999
#         \item Öffentliche Bekanntmachung: 22.01.1999
#         \item Öffentliche Auslegung: 01.02.1999 - 01.03.1999
#     \end{itemize}
#     \item \textbf{Erneuter Auslegungsbeschluss}
#     \begin{itemize}
#         \item Öffentliche Bekanntmachung: 08.11.1999
#         \item Öffentliche Bekanntmachung: 13.11.1999
#         \item Öffentliche Auslegung: 22.11.1999 - 06.12.1999
#     \end{itemize}
# \end{itemize}
#
# \end{document}
# ```
# #############################################
# ```latex
# \documentclass{article}
# \usepackage[utf8]{inputenc}
# \usepackage{graphicx}
#
# \begin{document}
#
# \section*{Schriftlicher Teil Bebauungsplan "Gewerbegebiet Hämmerich"}
# Stadt Laichingen, Gemarkung Feldstetten, Alb-Donau-Kreis, 19.06.2000
#
# \begin{flushright}
# Seite 9
# \end{flushright}
#
# \subsection*{Zweiter Erneuter Auslegungsbeschluss}
# \begin{itemize}
#     \item Öffentliche Bekanntmachung: 03.04.2000
#     \item Öffentliche Auslegung: 19.04.2000
#     \item Öffentliche Auslegung: 27.04.2000 - 11.05.2000
# \end{itemize}
#
# \subsection*{Satzungsbeschluss}
# 19.06.2000
#
# \subsection*{Ausgefertigt}
# Der textliche und zeichnerische Inhalt dieses Bebauungsplanes stimmt mit dem Satzungsbeschluß überein. Das Verfahren wurde ordnungsgemäß durchgeführt.
#
# \begin{flushright}
# Laichingen, den 20. Dez. 2000
# \end{flushright}
#
# \begin{tabbing}
# \hspace{6cm} \= \kill
# \hspace{6cm} \= \textit{Bürgermeister} \\
# \end{tabbing}
#
# \subsection*{Ortsübliche Bekanntmachung}
# \begin{flushright}
# 29. Dez. 2000
# \end{flushright}
#
# \subsection*{Damit wurde der Bebauungsplan rechtsverbindlich}
# \begin{flushright}
# Laichingen, den 29. Dez. 2000
# \end{flushright}
#
# \begin{tabbing}
# \hspace{6cm} \= \kill
# \hspace{6cm} \= \textit{Bürgermeister} \\
# \end{tabbing}
#
# \end{document}
# ```
# #############################################
# ```latex
# \documentclass{article}
# \usepackage[utf8]{inputenc}
# \usepackage{graphicx}
#
# \begin{document}
#
# \begin{flushright}
# 19.06.2000 \\
# 9833
# \end{flushright}
#
# \begin{center}
# \textbf{ÖRTLICHE BAUVORSCHRIFTEN (§ 74 (7) LBO) ZUM} \\
# \textbf{BEBBAUUNGSPLAN "GEWERBEGEBIET HIMMELREICH"} \\
# \textbf{STADT LAICHINGEN, GEMARKUNG FELDSTETTEN, ALB-DONAU-KREIS}
# \end{center}
#
# \begin{enumerate}
#     \item \textbf{Dacheindeckung (§ 74 (1) 1 LBO)} \\
#     Die Dachflächen sind mit roten bis rotbraunen, nicht glänzenden Materialien einzudecken.
#
#     \item \textbf{Werbeanlagen (§ 74 (1) 2 LBO)} \\
#     Werbeanlagen sind in den öffentlichen Grünflächen ausgeschlossen. Die Gesamtfläche aller Werbeanlagen darf pro Baugrundstück 20 m² nicht überschreiten. \\
#     Eine einzelne Werbeanlage darf nicht größer als 10 m² sein. \\
#     Unzulässig sind Werbeanlagen mit wechselndem und bewegtem Licht.
# \end{enumerate}
#
# \vspace{2cm}
#
# Aufgestellt: Reutlingen, den 19.06.2000
#
# \vspace{1cm}
#
# \includegraphics[width=0.2\textwidth]{signature.png} \\ % Assuming the signature is saved as signature.png
# Clemens Künstler \\
# Dipl.-Ing. Regierungsbaumeister \\
# Freier Architekt + Stadtplaner SRL
#
# \end{document}
# ```
# #############################################

# %%
# B2) OCR via GPT-4o / Kompletter schriflitcher Teil
# Idee: Komplettes PDF auf einmal einlesen, sodass Layout konsistent bleibt.
pdf_path = "../data/raw/bpläne/2_zeichnung_textteil_getrennt/F11-01-TT.pdf"
pdf_prompts = parser.pdf2prompts(pdf_path)

pdf_text = ava.request([
    *pdf_prompts,
    {
        "type": "text",
        "text": 'Extrahiere den kompletten Textinhalt. Output im LaTeX-Format.'
    },
])

pprint(pdf_text)
# Out:
# ```latex
# \documentclass{article}
# \usepackage[utf8]{inputenc}
# \usepackage{graphicx}
#
# \begin{document}
#
# \section*{Schriftlicher Teil (Teil B)}
# \textbf{Bebauungsplan "Gewerbegebiet Himmelreich"} \\
# Stadt Laichingen, Gemarkung Feldstetten, Alb-Donau-Kreis
#
# \subsection*{}
# Der Geltungsbereich wird durch das Planzeichen im Lageplan begrenzt. \\
# Lageplan M 1: 500
#
# \subsection*{}
# Für die planungsrechtlichen bzw. bauordnungsrechtlichen Festsetzungen gelten:
# \begin{itemize}
#     \item Baugesetzbuch (BauGB) in der Fassung der Bekanntmachung vom 27.08.1997 (BGBl. I. S. 2141).
#     \item Baunutzungsverordnung (BauNVO) in der Fassung der Bekanntmachung vom 23.01.1990 (BGBl. S. 132), zuletzt geändert am 22.04.1993 (BGBl. I. S. 466).
#     \item Planzeichenverordnung 1990 (PlanZV 90) in der Fassung der Bekanntmachung vom 18.12.1990 (BGBl. I. S. 58).
#     \item Landesbauordnung (LBO) in der Fassung der Bekanntmachung vom 08.08.1995 (GBl. S. 617).
# \end{itemize}
#
# \subsection*{Bisherige Festsetzungen:}
# Mit in Kraft treten dieses Bebauungsplanes treten im Geltungsbereich alle bisherigen gemeindlichen planungsrechtlichen und bauordnungsrechtlichen Festsetzungen außer Kraft.
#
#
# ewpage
#
# \section*{}
# \textbf{Schriftlicher Teil Bebauungsplan "Gewerbegebiet Himmelreich"} \\
# Stadt Laichingen, Gemarkung Feldstetten, Alb-Donau-Kreis, 19.06.2000
#
# \subsection*{}
# In Ergänzung der Planzeichnung wird folgendes festgesetzt:
#
# \subsubsection*{1. Planungsrechtliche Festsetzungen (§ 9 (1) und (2) BauGB und BauNVO)}
# \begin{itemize}
#     \item 1.1 Art der baulichen Nutzung (§§ 1 - 15 BauNVO)
#     \begin{itemize}
#         \item 1.1.1 Eingeschränktes Gewerbegebiet (GEE) (§ 8 BauNVO i.V.m. § 1 (4) BauNVO)
#         \begin{itemize}
#             \item 1.1.1.1 Zulässig sind / zulässig ist:
#             \begin{itemize}
#                 \item 1.1.1.1.1 Gewerbebetriebe, die das Wohnen nicht wesentlich stören, wobei bei Einzelhandelsbetrieben (gem. § 1 (5) BauNVO i.V.m. § 1 (9) BauNVO) nur die nicht innenstadtrelevanten Sortimente Kfz, Motorräder, Mopeds, Fahrräder, Kfz-Zubehör, Rasenmäher, Landmaschinen, Fahrrad- und Motorradzubehör, Brennstoffe und Mineralölerzeugnisse zulässig sind.
#                 \item 1.1.1.1.2 Der Verkauf von auf dem Grundstück produzierten Waren auf einer untergeordneten Fläche ist zulässig.
#             \end{itemize}
#             \item 1.1.1.2 Nicht zulässig sind / nicht zulässig ist:
#             \begin{itemize}
#                 \item 1.1.1.2.1 Nutzungen gemäß § 8 (3) Nr.3 BauNVO (Vergnügungsstätten) sind gemäß § 1 (6) BauNVO nicht Bestandteil des Bebauungsplans und damit nicht zulässig.
#                 \item 1.1.1.2.2 Einzelhandelsbetriebe mit innenstadtrelevanten und bestimmten nicht innenstadtrelevanten Sortimenten sind gemäß § 1 (5) BauNVO i.V.m. § 1 (9) BauNVO nicht zulässig.
#             \end{itemize}
#         \end{itemize}
#         \item 1.1.2 Gewerbegebiet (GE) (§ 8 BauNVO)
#         \begin{itemize}
#             \item 1.1.2.1 Zulässig sind / zulässig ist:
#             \begin{itemize}
#                 \item 1.1.2.1.1 Gewerbebetriebe aller Art, wobei bei Einzelhandelsbetrieben (gem. § 1 (5) BauNVO i.V.m. § 1 (9) BauNVO) nur die nicht innenstadtrelevanten Sortimente Kfz, Motorräder, Mopeds, Fahrräder, Kfz-Zubehör, Rasenmäher, Landmaschinen, Fahrrad- und Motorradzubehör, Brennstoffe und Mineralölerzeugnisse zulässig sind.
#                 \item 1.1.2.1.2 Der Verkauf von auf dem Grundstück produzierten Waren auf einer untergeordneten Fläche ist zulässig.
#             \end{itemize}
#             \item 1.1.2.2 Nicht zulässig sind / nicht zulässig ist:
#             \begin{itemize}
#                 \item 1.1.2.2.1 Nutzungen gemäß § 8 (3) Nr.3 BauNVO (Vergnügungsstätten) sind gemäß § 1 (6) BauNVO nicht Bestandteil des Bebauungsplans und damit nicht zulässig.
#                 \item 1.1.2.2.2 Einzelhandelsbetriebe mit innenstadtrelevanten und bestimmten nicht innenstadtrelevanten Sortimenten sind gemäß § 1 (5) BauNVO i.V.m. § 1 (9) BauNVO nicht zulässig.
#             \end{itemize}
#         \end{itemize}
#         \item 1.1.3 Innenstadtrelevante Sortimente gemäß 1.1.1.2.2 und 1.1.2.2.2 sind:
#         \begin{itemize}
#             \item Nahrungs- und Genussmittel einschließlich der Betriebe des Ernährungshandwerks
#             \item Drogeriewaren, Parfümeriewaren
#             \item Apothekenwaren
#             \item Blumen, zoologischer Bedarf
#             \item Oberbekleidung, Kürschnerwaren, sonstige Textilwaren, Wolle, Kurzwaren, Sportbekleidung
#             \item Schuhe, Lederwaren
#             \item Haushaltswaren, Unterhaltungselektronik, optische und feinmechanische Geräte, Fotowaren
#             \item Papier- und Schreibwaren, Bücher, Spielwaren
#             \item Uhren, Schmuck, Silberwaren
#             \item Musikalien, Ton- und Bildträger
#             \item Heimtextilien, Bettwaren, Gardinen und Zubehör
#         \end{itemize}
#         \item 1.1.4 Bestimmte nicht innenstadtrelevante Sortimente gemäß 1.1.1.2.2 und 1.1.2.2.2 sind:
#         \begin{itemize}
#             \item Möbel, Kücheneinrichtungen, Elektrogeräte (weiße Ware), Öfen, Herde, Elektroeinbaugeräte, Haushaltstechnik
#             \item Büromöbel, Büromaschinen, Computer, Büroorganisationsmittel, Büro- und Kommunikationstechnik (vorwiegender Absatz an gewerbliche Verwendung)
#             \item Holz, Bauelemente z.B. Fenster und Türen, Baustoffe, Sanitär / Fliesen, Installationsmaterial, Badeeinrichtungen und -ausstattung, Eisenwaren und Werkzeuge, Maschinen und -zubehör
#             \item Beleuchtungskörper, Leuchten, Elektroinstallationsbedarf
#             \item Teppiche, Bodenbeläge, Farben, Lacke, Tapeten, Malereibedarf
#             \item Pflanzen, Pflege- und Düngemittel, Torf, Erde, Pflanzengefäße, Gartenwerkzeuge und -maschinen, Gartenmöbel, Gartenhäuser, Gewächshäuser u.a.
#         \end{itemize}
#         \item 1.1.5 Randsortimente
#         \begin{itemize}
#             \item Innenstadtrelevante, branchentypische Randsortimente sind in den zulässigen Verkaufsflächen gemäß 1.1.1.1.1 und 1.1.2.1.1 bis zu einer maximalen Fläche von 10\% der zulässigen Verkaufsfläche ausnahmsweise zulässig.
#         \end{itemize}
#         \item 1.1.6 Verkaufsfläche
#         \begin{itemize}
#             \item Verkaufsfläche gemäß 1.1.1.5 ist die gesamte, dem Kunden zugängliche Fläche einschließlich Vorkassenzone und Verkaufsfläche im Freien mit Ausnahme der Kundensozialräume (WC und ähnliches).
#         \end{itemize}
#     \end{itemize}
#     \item 1.2 Maß der baulichen Nutzung (§ 16 - 21 BauNVO)
#     \begin{itemize}
#         \item 1.2.1 Grundflächenzahl (§ 19 BauNVO) - siehe Einschreibung im Lageplan -
#         \item 1.2.2 Geschossflächenzahl (§ 20 BauNVO) - siehe Einschreibung im Lageplan -
#         \item 1.2.3 Höhe der baulichen Anlagen (§ 18 BauNVO) - siehe Einschreibung im Lageplan - Die Gebäudehöhe wird gemessen von der Erdgeschoßfußbodenhöhe (EFH) bis zur Schnittkante zwischen Außenwand und Dachhaut bzw. bis zur Oberkante Firstziegel.
#     \end{itemize}
#     \item 1.3 Bauweise (§ 22 BauNVO) - siehe Einschreibung im Lageplan - abweichende Bauweise. Es gilt die offene Bauweise, jedoch sind die Gebäudelängen nicht begrenzt.
#     \item 1.4 Überbaubare Grundstücksfläche (§ 9 (1) 2 BauGB) Die überbaubare Grundstücksfläche wird durch die Festsetzung von Baugrenzen in der Planzeichnung bestimmt. Garagen im Sinne von § 12 BauNVO und Nebenanlagen im Sinne des § 14 BauNVO sowie Anlagen der Fremdwerbung und bauliche Anlagen, die nach Landesrecht in den Abstandsflächen zulässig sind oder zugelassen werden können, sind nur innerhalb der überbaubaren Grundstücksflächen zulässig.
#     \item 1.5 Von der Bebauung freizuhaltende Flächen und Sichtfelder (§ 9 (1) 10 BauGB) - siehe Einschreibung im Lageplan - Auf den, zugunsten von EVS und der Stadt (Leitungsrecht 1 und 2) sowie entlang der B 28 festgesetzten, von der Bebauung freizuhaltenden Grundstücksflächen, sind Garagen im Sinne von § 12 BauNVO und Nebenanlagen im Sinne von § 14 BauNVO unzulässig. Die im Lageplan ausgewiesenen Sichtfelder im Bereich der Straßeneinmündungen sind von Bäumen und Sträuchern sowie weiteren Anlagen über 0,70 m Höhe, gemessen von der Fahrbahnboberkante, freizuhalten bzw. freizumachen.
#     \item 1.6 Flächen und Maßnahmen zum Schutz, zur Pflege und zur Entwicklung von Boden, Natur und Landschaft (§ 9 (1) 20 BauGB)
#     \begin{itemize}
#         \item Maßnahme 1: Halbtrockenrasen Die gekennzeichneten Hangbereiche sind durch geeignete Maßnahmen in nächstforstame, teilweise gebölsierte Halbtrockenrasen zurückzuverwandeln. Dazu sind die Hybridpappeln zu fällen und auf ca. 50\% der Fläche ist der Gehölzaufwuchs zu roden. Ablagerungen sind zu entfernen und über einen Zeitraum von 5 Jahren sind die Flächen 1-mal jährlich zu mähen einschließlich Abfuhr des Mähguts.
#         \item Maßnahme 2: Gewässer- und Bodenschutz Die Stellplatzflächen sind mit wasserdurchlässigen Materialien wie Rasenpflaster, offenporigem Pflaster, Schotterrasen o. ä. zu befestigen, sofern dort keine Umlade- bzw. Wartungsarbeiten stattfinden.
#     \end{itemize}
#     \item 1.7 Leitungsrechte (§ 9 (1) 13 und 21 BauGB) - siehe Einschreibung im Lageplan -
#     \begin{itemize}
#         \item LR 1: Leitungsrecht zugunsten der EnBW betr. Herstellung und Wartung von elektrischen Leitungen.
#         \item LR 2: Leitungsrecht zugunsten der Stadt Laichingen betr. Herstellung und Wartung einer Wasserleitung DN 150.
#     \end{itemize}
#     \item 1.8 Flächen für das Anpflanzen von Bäumen, Sträuchern und sonstigen Bepflanzungen (§ 9 (1) 25a BauGB)
#     \begin{itemize}
#         \item Pflanzgebot 1 Straßenbäume entlang der B 28 Entlang der B 28 sind hochstämmige Bergahorn (Acer pseudoplatanus) mit mindestens 20/25 cm Stammumfang zu pflanzen und dauerhaft zu erhalten. Die im Grünordnungsplan bzw. Bebauungsplan vorgegebenen Standorte dienen als Anhaltspunkt. Eine Abweichung um bis zu 2,00 m ist zulässig. Die Flächen unter den Bäumen sind als extensive Wiesenfläche anzusäen und zu unterhalten.
#         \item Pflanzgebot 2 Straßenbäume im Wendehammer Im Wendebereich der Straße "B" sind 3 hochstämmige Bergahorn (Acer pseudoplatanus) mit mindestens 20/25 cm Stammumfang zu pflanzen und dauerhaft zu erhalten.
#         \item Pflanzgebot 3 Obstbäume Am Fuß des Trockenhangs sind ortstypische Hochstamm-Apfelbäume zu pflanzen und dauerhaft zu erhalten. Die im Grünordnungsplan bzw. im Bebauungsplan vorgegebenen Standorte dienen als Anhaltspunkt. Eine Abweichung um bis zu 2,00 m ist zulässig. Die Flächen unter den Bäumen sind als extensive Wiesenfläche anzusäen und zu unterhalten.
#         \item Pflanzgebot 4 Gehölzriegel zur Landschaft Innerhalb der gekennzeichneten Fläche ist ein 2-3 reihiger Gehölzriegel aus ausschließlich standorttypischen Bäumen und Sträuchern der Pflanzlisten 1 und 2 anzulegen und dauerhaft zu erhalten. Die Pflanzung muß mindestens 70\% der Fläche einnehmen. Pro 100 laufende Meter Länge der Pflanzung müssen dabei mindestens 10 Bäume verwendet werden. Zaunanlagen sind in die Pflanzung zu integrieren und müssen mindestens 2 Meter Abstand zur Grenze aufweisen.
#         \item Pflanzgebot 5 Schlehengebüsch Innerhalb der gekennzeichneten Flächen ist 1-2 reihige Gehölzriegel aus ausschließlich standorttypischen Sträuchern der Pflanzliste 2 anzulegen und dauerhaft zu erhalten. 80\% der Gehölze müssen dabei Schlehen (Prunus spinosa) sein.
#         \item Pflanzgebot 6 Gehölze auf den Baugrundstücken Innerhalb der gekennzeichneten Flächen sind einzelne Bäume und Strauchgruppen aus ausschließlich Gehölzen der Pflanzlisten 1 und 2 anzulegen und dauerhaft zu erhalten. Die restlichen Flächen sind als extensive Rasenflächen anzusäen. Die Gehölzgruppen müssen mindestens 80\% der Vegetationsfläche einnehmen, pro 100 m laufender Meter Grundstücksgrenze müssen mindestens 3 Bäume gepflanzt werden. Ausgenommen sind alle Zugangs- und Zufahrtsbereiche zu den Grundstücken.
#         \item Pflanzgebot 7 Bepflanzung der Stellplatzflächen Zur Begrünung der Stellplätze ist je 8 Plätze ein hochstämmiger Laubbaum mit mindestens 20/25 cm Stammumfang zu pflanzen und dauerhaft zu erhalten. Die Pflanzfläche muß mindestens 6,00 m² betragen. Befahrbare Abdeckungen der Baumscheiben (Baumroste) sind zulässig.
#         \item Pflanzgebot 8 Gehölzriegel zur Landschaft Innerhalb der gekennzeichneten Fläche ist ein 2-3 reihiger Gehölzriegel aus ausschließlich standorttypischen Sträuchern der Pflanzliste 2 anzulegen und dauerhaft zu erhalten. Die Pflanzung muß mindestens 70\% der Fläche einnehmen. Zaunanlagen sind in die Bepflanzung zu integrieren und müssen mindestens 2 Meter Abstand zur Grenze aufweisen.
#     \end{itemize}
#     \item 1.9 Flächen mit Bindungen für Bepflanzungen und für die Erhaltung von Bäumen, Sträuchern und sonstigen Bepflanzungen (§ 9 (1) 25b BauGB) Das gekennzeichnete Ligustergebüsch ist zu erhalten. Die beiden Weiden innerhalb dieses Gebüsches sind jedoch zu entfernen und durch die Straßenbäume des Pflanzgebotes 1 zu ersetzen.
# \end{itemize}
#
# \subsubsection*{2. Hinweise}
# \begin{itemize}
#     \item 2.1 Bodenschutz Um die wertvolle Ressource Boden zu schonen, sind die Hinweise der Informationsschrift des Ministeriums für Ernährung, Landwirtschaft, Umwelt und Forsten Baden-Württemberg "Erhaltung fruchtbaren und kulturfähigen Bodens bei Flächeninanspruchnahmen" zu beachten. Bodenaushub hat möglichst im Baugebiet zu verbleiben und ist dort wiederzuverwenden (z.B. an Böschungen, Lärmschutzwällen). Mutterboden ist getrennt zwischenzulagern und für die Gestaltung der Außenanlagen einzusetzen. Überschüssiger Mutterboden muß auf Oberboden-deponien gebracht werden. Bei Auf- und Abtrag von Bodenhöhen ist ein Massenausgleich anzustreben. Werden während der Aushubarbeiten außerhalb der altlastenverdächtigen Flächen Verunreinigungen des Bodens festgestellt (z.B. Müllrückstände, Verfärbungen des Bodens, Geruchsbelästigungen o. ä.), ist das Landratsamt Alb-Donau-Kreis, Tel. 0731/185-1561 oder 1562 sofort zu benachrichtigen.
#     \item 2.2 Archäologische Funde Sollten im Zuge von Erdarbeiten archäologische Funde (z.B. Mauern, Gruben, Brandschichten) angeschnitten oder Funde gemacht werden (z.B. Scherben, Metallteile, Knochen), ist das Landesdenkmalamt, Abt. Archäologische Denkmalpflege, unverzüglich zu benachrichtigen. Auf § 20 DSchG wird verwiesen.
#     \item 2.

# %%
# C1) Ein Thread
# Nachteil: Visueller Kontext geht verloren
text_prompts = parser.text2prompts(data_list)
msg = ava.request([
    *text_prompts,
        {
        "type": "text",
        "text": 'Extrahiere alle Informationen zu den folgenden Themen: Art der baulichen Nutzung, Maß der baulichen Nutzung, Bauweise, überbaubare Grundstücksfläche.'
    }
])

pprint(msg)
# Out:
# Hier sind die extrahierten Informationen zu den Themen "Art der baulichen Nutzung", "Maß der baulichen Nutzung", "Bauweise" und "überbaubare Grundstücksfläche":
#
# ### Art der baulichen Nutzung
# #### Eingeschränktes Gewerbegebiet (GEE) (§ 8 BauNVO i.V.m. § 1 (4) BauNVO)
# - **Zulässig sind:**
#   - Gewerbebetriebe, die das Wohnen nicht wesentlich stören, wobei bei Einzelhandelsbetrieben nur die nicht innenstadtrelevanten Sortimente (Kfz, Motorräder, Mopeds, Fahrräder, Kfz-Zubehör, Rasenmäher, Landmaschinen, Fahrrad- und Motorradzubehör, Brennstoffe und Mineralölerzeugnisse) zulässig sind.
#   - Der Verkauf von auf dem Grundstück produzierten Waren auf einer untergeordneten Fläche ist zulässig.
# - **Nicht zulässig sind:**
#   - Nutzungen gemäß § 8 (3) Nr. 3 BauNVO (Vergnügungsstätten) sind nicht zulässig.
#   - Einzelhandelsbetriebe mit innenstadtrelevanten und bestimmten nicht innenstadtrelevanten Sortimenten sind nicht zulässig.
#
# #### Gewerbegebiet (GE) (§ 8 BauNVO)
# - **Zulässig sind:**
#   - Gewerbebetriebe aller Art, wobei bei Einzelhandelsbetrieben nur die nicht innenstadtrelevanten Sortimente (Kfz, Motorräder, Mopeds, Fahrräder, Kfz-Zubehör, Rasenmäher, Landmaschinen, Fahrrad- und Motorradzubehör, Brennstoffe und Mineralölerzeugnisse) zulässig sind.
#   - Der Verkauf von auf dem Grundstück produzierten Waren auf einer untergeordneten Fläche ist zulässig.
# - **Nicht zulässig sind:**
#   - Nutzungen gemäß § 8 (3) Nr. 3 BauNVO (Vergnügungsstätten) sind nicht zulässig.
#   - Einzelhandelsbetriebe mit innenstadtrelevanten und bestimmten nicht innenstadtrelevanten Sortimenten sind nicht zulässig.
#
# ### Maß der baulichen Nutzung (§ 16 - 21 a BauNVO)
# - **Grundflächenzahl (§ 19 BauNVO):** - siehe Einträge im Lageplan -
# - **Geschossflächenzahl (§ 20 BauNVO):** - siehe Einträge im Lageplan -
# - **Höhe der baulichen Anlagen (§ 18 BauNVO):** - siehe Einträge im Lageplan -
#   - Die Gebäudehöhe wird gemessen von der Erdgeschossfußbodenhöhe (EFH) bis zur Schnittkante zwischen Außenwand und Dachhaut bzw. bis zur Oberkante Firstziegel.
#
# ### Bauweise (§ 22 BauNVO)
# - **Bauweise:** - siehe Einschnitte im Lageplan -
#   - a = abweichende Bauweise. Es gilt die offene Bauweise, jedoch sind die Gebäudelängen nicht begrenzt.
#
# ### Überbaubare Grundstücksfläche (§ 9 (1) 2 BauGB)
# - **Überbaubare Grundstücksfläche:** Die überbaubare Grundstücksfläche wird durch die Festsetzung von Baugrenzen in der Planzeichnung bestimmt.
#   - Garagen im Sinne von § 12 BauNVO und Nebenanlagen im Sinne des § 14 BauNVO sowie Anlagen der Fremdenwerbung und bauliche Anlagen, die nach Landesrecht in den Abstandsflächen zulässig sind oder zugelassen werden können, sind nur innerhalb der überbaubaren Grundstücksflächen zulässig.
#
# Diese Informationen wurden aus den bereitgestellten LaTeX-Dokumenten extrahiert und zusammengefasst.

# %%
# C2) Mehrere Threads – Extrahierter Text
# Nachteile: 
# * Visueller Kontext geht verloren
# * Fehlender Kontext zwischen den Chunks
# * Lösung enthält exkterne Logik via Vektor-Store
async def run(page_content):
    msg = ava.request([
        {
            "type": "text",
            "text": 'Extrahiere alle Informationen zu den folgenden Themen: Art der baulichen Nutzung, Maß der baulichen Nutzung, Bauweise, überbaubare Grundstücksfläche.'
        },
        {
            "type": "text",
            "text": page_content
        },
    ])
    return msg

prompt_chain = list(map(lambda page_content: run(page_content), data_list))
results = await asyncio.gather(*prompt_chain)
pprint(results)
# Out:
# Der bereitgestellte Text enthält keine spezifischen Informationen zu den Themen "Art der baulichen Nutzung", "Maß der baulichen Nutzung", "Bauweise" und "überbaubare Grundstücksfläche". Der Text beschreibt lediglich die rechtlichen Grundlagen und die Geltungsbereiche des Bebauungsplans "Gewerbegebiet Himmelreich" in der Stadt Laichingen, Gemarkung Feldstetten, Alb-Donau-Kreis.
#
# Um die gewünschten Informationen zu extrahieren, müssten detaillierte Festsetzungen oder Regelungen zu diesen Themen im Bebauungsplan enthalten sein. Da diese Informationen im bereitgestellten Text fehlen, kann keine Extraktion erfolgen.
# #############################################
# Hier sind die extrahierten Informationen zu den Themen "Art der baulichen Nutzung", "Maß der baulichen Nutzung", "Bauweise" und "überbaubare Grundstücksfläche" aus dem bereitgestellten Dokument:
#
# ### Art der baulichen Nutzung
# #### Eingeschränktes Gewerbegebiet (GEE) (§ 8 BauNVO i.V.m. § 1 (4) BauNVO)
# - **Zulässig sind:**
#   - Gewerbebetriebe, die das Wohnen nicht wesentlich stören.
#   - Einzelhandelsbetriebe mit nicht innenstadtrelevanten Sortimenten wie Kfz, Motorräder, Mopeds, Fahrräder, Kfz-Zubehör, Rasenmäher, Landmaschinen, Fahrrad- und Motorradzubehör, Brennstoffe und Mineralölerzeugnisse.
#   - Der Verkauf von auf dem Grundstück produzierten Waren auf einer untergeordneten Fläche.
#
# - **Nicht zulässig sind:**
#   - Nutzungen gemäß § 8 (3) Nr. 3 BauNVO (Vergnügungsstätten).
#   - Einzelhandelsbetriebe mit innenstadtrelevanten und bestimmten nicht innenstadtrelevanten Sortimenten.
#
# #### Gewerbegebiet (GE) (§ 8 BauNVO)
# - **Zulässig sind:**
#   - Gewerbebetriebe aller Art.
#   - Einzelhandelsbetriebe mit nicht innenstadtrelevanten Sortimenten wie Kfz, Motorräder, Mopeds, Fahrräder, Kfz-Zubehör, Rasenmäher, Landmaschinen, Fahrrad- und Motorradzubehör, Brennstoffe und Mineralölerzeugnisse.
#   - Der Verkauf von auf dem Grundstück produzierten Waren auf einer untergeordneten Fläche.
#
# - **Nicht zulässig sind:**
#   - Nutzungen gemäß § 8 (3) Nr. 3 BauNVO (Vergnügungsstätten).
#   - Einzelhandelsbetriebe mit innenstadtrelevanten und bestimmten nicht innenstadtrelevanten Sortimenten.
#
# ### Maß der baulichen Nutzung
# Im bereitgestellten Dokument sind keine spezifischen Informationen zum Maß der baulichen Nutzung enthalten.
#
# ### Bauweise
# Im bereitgestellten Dokument sind keine spezifischen Informationen zur Bauweise enthalten.
#
# ### Überbaubare Grundstücksfläche
# Im bereitgestellten Dokument sind keine spezifischen Informationen zur überbaubaren Grundstücksfläche enthalten.
#
# Falls weitere Informationen zu den nicht abgedeckten Themen benötigt werden, könnte es hilfreich sein, das vollständige Dokument oder zusätzliche Abschnitte zu überprüfen.
# #############################################
# Hier sind die extrahierten Informationen zu den angefragten Themen aus dem Dokument:
#
# ### Art der baulichen Nutzung
# Das Dokument enthält keine spezifischen Informationen zur Art der baulichen Nutzung.
#
# ### Maß der baulichen Nutzung
# Das Maß der baulichen Nutzung wird in den folgenden Unterpunkten behandelt:
#
# #### Grundflächenzahl (§ 19 BauNVO)
# - Die spezifischen Werte sind im Lageplan zu finden.
#
# #### Geschossflächenzahl (§ 20 BauNVO)
# - Die spezifischen Werte sind im Lageplan zu finden.
#
# #### Höhe der baulichen Anlagen (§ 18 BauNVO)
# - Die Gebäudehöhe wird gemessen von der Erdgeschossfußbodenhöhe (EFH) bis zur Schnittkante zwischen Außenwand und Dachhaut bzw. bis zur Oberkante Firstziegel.
#
# ### Bauweise
# Das Dokument enthält keine spezifischen Informationen zur Bauweise.
#
# ### Überbaubare Grundstücksfläche
# Das Dokument enthält keine spezifischen Informationen zur überbaubaren Grundstücksfläche.
#
# Zusammenfassend lässt sich sagen, dass das Dokument hauptsächlich Informationen zum Maß der baulichen Nutzung enthält, während spezifische Details zur Art der baulichen Nutzung, Bauweise und überbaubaren Grundstücksfläche fehlen.
# #############################################
# Hier sind die extrahierten Informationen zu den angefragten Themen aus dem bereitgestellten LaTeX-Dokument:
#
# ### Art der baulichen Nutzung
# Im bereitgestellten Text sind keine spezifischen Informationen zur Art der baulichen Nutzung enthalten.
#
# ### Maß der baulichen Nutzung
# Im bereitgestellten Text sind keine spezifischen Informationen zum Maß der baulichen Nutzung enthalten.
#
# ### Bauweise
# - **Bauweise (§ 22 BauNVO)**:
#   - Es gilt die offene Bauweise.
#   - Die Gebäudelängen sind nicht begrenzt.
#   - Abweichende Bauweise ist möglich (siehe Einschnitte im Lageplan).
#
# ### Überbaubare Grundstücksfläche
# - **Überbaubare Grundstücksfläche (§ 9 (1) 2 BauGB)**:
#   - Die überbaubare Grundstücksfläche wird durch die Festsetzung von Baugrenzen in der Planzeichnung bestimmt.
#   - Garagen im Sinne von § 12 BauNVO und Nebenanlagen im Sinne des § 14 BauNVO sowie Anlagen der Fremdenwerbung und bauliche Anlagen, die nach Landesrecht in den Abstandsflächen zulässig sind oder zugelassen werden können, sind nur innerhalb der überbaubaren Grundstücksflächen zulässig.
#
# Diese Informationen decken die angefragten Themen ab, soweit sie im bereitgestellten Text enthalten sind.
# #############################################
# Der bereitgestellte Text enthält keine Informationen zu den Themen "Art der baulichen Nutzung", "Maß der baulichen Nutzung", "Bauweise" und "überbaubare Grundstücksfläche". Der Text bezieht sich ausschließlich auf Pflanzgebote und die Anpflanzung von Bäumen, Sträuchern und sonstigen Bepflanzungen entlang bestimmter Bereiche und innerhalb gekennzeichneter Flächen.
#
# Falls du Informationen zu den genannten Themen benötigst, solltest du den entsprechenden Abschnitt des Dokuments bereitstellen, der diese Informationen enthält.
# #############################################
# Im bereitgestellten Dokument sind keine spezifischen Informationen zu den Themen "Art der baulichen Nutzung", "Maß der baulichen Nutzung", "Bauweise" und "überbaubare Grundstücksfläche" enthalten. Das Dokument konzentriert sich hauptsächlich auf Pflanzlisten, Flächen mit Bindungen für Bepflanzungen und Hinweise zum Bodenschutz.
#
# Falls du weitere Informationen zu den genannten Themen benötigst, könnte es hilfreich sein, ein anderes Dokument oder einen anderen Abschnitt des Bebauungsplans zu konsultieren.
# #############################################
# Im bereitgestellten Text sind keine Informationen zu den Themen "Art der baulichen Nutzung", "Maß der baulichen Nutzung", "Bauweise" und "überbaubare Grundstücksfläche" enthalten. Der Text behandelt stattdessen Themen wie archäologische Funde, Grundwasserschutz und Schallimmissionen.
# #############################################
# Im bereitgestellten Dokument sind keine Informationen zu den Themen "Art der baulichen Nutzung", "Maß der baulichen Nutzung", "Bauweise" und "überbaubare Grundstücksfläche" enthalten. Das Dokument enthält lediglich Verfahrensvermerke zum Bebauungsplan "Gewerbegebiet Himmelreich" der Stadt Laichingen, Gemarkung Feldstetten, Alb-Donau-Kreis.
#
# Falls du Informationen zu den genannten Themen benötigst, solltest du ein anderes Dokument oder einen anderen Abschnitt des Bebauungsplans konsultieren, der spezifische Regelungen und Festsetzungen zu diesen Aspekten enthält.
# #############################################
# Im bereitgestellten Dokument sind keine Informationen zu den Themen "Art der baulichen Nutzung", "Maß der baulichen Nutzung", "Bauweise" und "überbaubare Grundstücksfläche" enthalten. Das Dokument enthält lediglich formale Angaben zum Bebauungsplan "Gewerbegebiet Hämmerich" der Stadt Laichingen, wie z.B. Beschlüsse, Auslegungsdaten und Bekanntmachungen.
# #############################################
# In dem bereitgestellten Dokument sind keine Informationen zu den Themen "Art der baulichen Nutzung", "Maß der baulichen Nutzung", "Bauweise" und "überbaubare Grundstücksfläche" enthalten. Das Dokument behandelt lediglich die folgenden Punkte:
#
# 1. **Dacheindeckung (§ 74 (1) 1 LBO)**:
#    - Die Dachflächen sind mit roten bis rotbraunen, nicht glänzenden Materialien einzudecken.
#
# 2. **Werbeanlagen (§ 74 (1) 2 LBO)**:
#    - Werbeanlagen sind in den öffentlichen Grünflächen ausgeschlossen.
#    - Die Gesamtfläche aller Werbeanlagen darf pro Baugrundstück 20 m² nicht überschreiten.
#    - Eine einzelne Werbeanlage darf nicht größer als 10 m² sein.
#    - Unzulässig sind Werbeanlagen mit wechselndem und bewegtem Licht.
#
# Es gibt keine weiteren Informationen zu den von dir angefragten Themen in diesem Dokument.
# #############################################

# %%
# C3) Vector Store
# Nachteile:
# * Visueller Kontext geht verloren.
# * Größe von k schränkte vollständige Extraktion ein.
documents = list(map(lambda item: DotMap({"page_content":item[1], "metadata": DotMap({"page": item[0]+1})}), enumerate(data_list)))
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000)
splits = text_splitter.split_documents(documents)
vectorstore = Chroma()
vectorstore.reset_collection()
vectorstore = Chroma.from_documents(documents=splits, embedding=embeddings_model)
query = 'Extrahiere alle Informationen zu den folgenden Themen: Art der baulichen Nutzung, Maß der baulichen Nutzung, Bauweise, überbaubare Grundstücksfläche.'
retrieved_docs = vectorstore.similarity_search_with_relevance_scores(query, k=25)
retrieved_text = list(map(lambda item: item[0].page_content, retrieved_docs))
text_prompts = parser.text2prompts(retrieved_text)

msg = ava.request([
    *text_prompts,
        {
        "type": "text",
        "text": query
    }
])

pprint(len(retrieved_docs))
pprint(msg)
# Out:
# 25
# Hier sind die extrahierten Informationen zu den angeforderten Themen aus dem LaTeX-Dokument:
#
# ### Art der baulichen Nutzung
#
# #### Eingeschränktes Gewerbegebiet (GEE) (§ 8 BauNVO i.V.m. § 1 (4) BauNVO)
# - **Zulässig sind / zulässig ist:**
#   - Gewerbebetriebe, die das Wohnen nicht wesentlich stören, wobei bei Einzelhandelsbetrieben (gem. § 1 (5) BauNVO i.V.m. § 1 (9) BauNVO) nur die nicht innenstadtrelevanten Sortimente Kfz, Motorräder, Mopeds, Fahrräder, Kfz-Zubehör, Rasenmäher, Landmaschinen, Fahrrad- und Motorradzubehör, Brennstoffe und Mineralölerzeugnisse zulässig sind.
#   - Der Verkauf von auf dem Grundstück produzierten Waren auf einer untergeordneten Fläche ist zulässig.
# - **Nicht zulässig sind / nicht zulässig ist:**
#   - Nutzungen gemäß § 8 (3) Nr. 3 BauNVO (Vergnügungsstätten) sind gemäß § 1 (6) BauNVO nicht Bestandteil des Bebauungsplans und damit nicht zulässig.
#   - Einzelhandelsbetriebe mit innenstadtrelevanten und bestimmten nicht innenstadtrelevanten Sortimenten sind gemäß § 1 (5) BauNVO i.V.m. § 1 (9) BauNVO nicht zulässig.
#
# #### Gewerbegebiet (GE) (§ 8 BauNVO)
# - **Zulässig sind / zulässig ist:**
#   - Gewerbebetriebe aller Art, wobei bei Einzelhandelsbetrieben (gem. § 1 (5) BauNVO i.V.m. § 1 (9) BauNVO) nur die nicht innenstadtrelevanten Sortimente Kfz, Motorräder, Mopeds, Fahrräder, Kfz-Zubehör, Rasenmäher, Landmaschinen, Fahrrad- und Motorradzubehör, Brennstoffe und Mineralölerzeugnisse zulässig sind.
#   - Der Verkauf von auf dem Grundstück produzierten Waren auf einer untergeordneten Fläche ist zulässig.
# - **Nicht zulässig sind / nicht zulässig ist:**
#   - Nutzungen gemäß § 8 (3) Nr. 3 BauNVO (Vergnügungsstätten) sind gemäß § 1 (6) BauNVO nicht Bestandteil des Bebauungsplans und damit nicht zulässig.
#
# ### Maß der baulichen Nutzung (§ 16 - 21 a BauNVO)
#
# #### Grundflächenzahl (§ 19 BauNVO)
# - siehe Einträge im Lageplan
#
# #### Geschossflächenzahl (§ 20 BauNVO)
# - siehe Einträge im Lageplan
#
# #### Höhe der baulichen Anlagen (§ 18 BauNVO)
# - siehe Einträge im Lageplan
# - Die Gebäudehöhe wird gemessen von der Erdgeschossfußbodenhöhe (EFH) bis zur Schnittkante zwischen Außenwand und Dachhaut bzw. bis zur Oberkante Firstziegel.
#
# ### Bauweise (§ 22 BauNVO)
# - siehe Einschnitte im Lageplan
# - a = abweichende Bauweise. Es gilt die offene Bauweise, jedoch sind die Gebäudelängen nicht begrenzt.
#
# ### Überbaubare Grundstücksfläche (§ 9 (1) 2 BauGB)
# - Die überbaubare Grundstücksfläche wird durch die Festsetzung von Baugrenzen in der Planzeichnung bestimmt.
# - Garagen im Sinne von § 12 BauNVO und Nebenanlagen im Sinne des § 14 BauNVO sowie Anlagen der Fremdenwerbung und bauliche Anlagen, die nach Landesrecht in den Abstandsflächen zulässig sind oder zugelassen werden können, sind nur innerhalb der überbaubaren Grundstücksflächen zulässig.
