# %% [markdown]
# # 3. QA Agent (GPT-4o)
#
# Simplifizierte RAG Anwendung für QA-Prompts.
#
# * QA Tests (L04, F11, B872A)
# * Prüfschritte bzgl. B-Plan L04

# %%
from utils.openai import OpenAI
from utils.parser import Parser
from utils.runner import Runner
from utils.pprint import pprint

instructions = 'Du bist ein Chat-Bot der mit Hilfe der vorliegenden Informationen Fragen beantwortet. Helfen die gegeben Informationen nicht um eine Antwort zu formulieren, antworte mit "Das ist mir nicht bekannt".'
gerty = OpenAI(instructions)
parser = Parser()
runner = Runner()

# %% [markdown]
# ### Question & Answering

# %%
# 0) Test
msg0 = gerty.request([
    {
        "type": "text", 
        "text": "Wie ist das Wetter?"
    },
])
pprint(msg0)
# Out:
# Das ist mir nicht bekannt.

# %%
# 1) Bebauungsplan L04-01
# %store -r msg211_l04_nz msg211_l04_ze msg221_l04_nz msg231_l04_tt
context = parser.text2prompts([f'Zeichenerklärung: {msg211_l04_nz}, {msg211_l04_ze}', f'Planzeichnung: {msg221_l04_nz}', f'Textteil: {msg231_l04_tt}'])
gerty.addContext(context)
msg1 = gerty.request([
    {
        "type": "text", 
        "text": "Wieviel Nutzungsschablonen enthält die Planzeichnung?"
    },
    {
        "type": "text", 
        "text": "Gebe alle Nutzungsschablonen im JSON Format aus."
    },
    {
        "type": "text", 
        "text": 'Erläutere die Werte in den Nutzungsschablonen anhand der Festsetzungen in der Zeichenerklärung und dem Textteil.'
    }
])
pprint(msg1)
gerty.clearContext()
# Out:
# Die Planzeichnung enthält insgesamt 15 Nutzungsschablonen. Hier sind alle Nutzungsschablonen im JSON-Format:
#
# ```json
# [
#   {
#     "Baugebiet": "GE 2",
#     "Zahl der Vollgeschosse": "II",
#     "Grundflächenzahl": "0,6",
#     "Geschossflächenzahl": "1,2",
#     "Bauweise": "0",
#     "Dachform und Dachneigung": "SD DN 12-18°"
#   },
#   {
#     "Baugebiet": "WA",
#     "Zahl der Vollgeschosse": "I",
#     "Grundflächenzahl": "0,3",
#     "Geschossflächenzahl": "0,5",
#     "Bauweise": "0",
#     "Dachform und Dachneigung": "SD DN 28-33°"
#   },
#   {
#     "Baugebiet": "WA",
#     "Zahl der Vollgeschosse": "I",
#     "Grundflächenzahl": "0,3",
#     "Geschossflächenzahl": "0,5",
#     "Bauweise": "0",
#     "Dachform und Dachneigung": "SD DN 28-33°"
#   },
#   {
#     "Baugebiet": "WA",
#     "Zahl der Vollgeschosse": "I",
#     "Grundflächenzahl": "0,3",
#     "Geschossflächenzahl": "0,5",
#     "Bauweise": "0",
#     "Dachform und Dachneigung": "SD DN 28-33°"
#   },
#   {
#     "Baugebiet": "MI",
#     "Zahl der Vollgeschosse": "II",
#     "Grundflächenzahl": "0,4",
#     "Geschossflächenzahl": "0,5",
#     "Bauweise": "0",
#     "Dachform und Dachneigung": "SD DN 28-33°"
#   },
#   {
#     "Baugebiet": "WR",
#     "Zahl der Vollgeschosse": "I",
#     "Grundflächenzahl": "0,5",
#     "Geschossflächenzahl": "-",
#     "Bauweise": "g",
#     "Dachform und Dachneigung": "FD"
#   },
#   {
#     "Baugebiet": "WA",
#     "Zahl der Vollgeschosse": "I",
#     "Grundflächenzahl": "0,3",
#     "Geschossflächenzahl": "0,5",
#     "Bauweise": "0",
#     "Dachform und Dachneigung": "SD DN 28-33°"
#   },
#   {
#     "Baugebiet": "WA",
#     "Zahl der Vollgeschosse": "I",
#     "Grundflächenzahl": "0,5",
#     "Geschossflächenzahl": "-",
#     "Bauweise": "0",
#     "Dachform und Dachneigung": "FD"
#   },
#   {
#     "Baugebiet": "WR",
#     "Zahl der Vollgeschosse": "I",
#     "Grundflächenzahl": "0,3",
#     "Geschossflächenzahl": "0,5",
#     "Bauweise": "0",
#     "Dachform und Dachneigung": "SD-DN 28-33°"
#   },
#   {
#     "Baugebiet": "WA",
#     "Zahl der Vollgeschosse": "I",
#     "Grundflächenzahl": "0,3",
#     "Geschossflächenzahl": "0,5",
#     "Bauweise": "0",
#     "Dachform und Dachneigung": "SD-DN 28-33°"
#   },
#   {
#     "Baugebiet": "WA",
#     "Zahl der Vollgeschosse": "I",
#     "Grundflächenzahl": "0,5",
#     "Geschossflächenzahl": "-",
#     "Bauweise": "g",
#     "Dachform und Dachneigung": "FD"
#   },
#   {
#     "Baugebiet": "WA",
#     "Zahl der Vollgeschosse": "I",
#     "Grundflächenzahl": "0,3",
#     "Geschossflächenzahl": "0,5",
#     "Bauweise": "0",
#     "Dachform und Dachneigung": "SD-DN 28-33°"
#   },
#   {
#     "Baugebiet": "MI",
#     "Zahl der Vollgeschosse": "I",
#     "Grundflächenzahl": "0,4",
#     "Geschossflächenzahl": "0,5",
#     "Bauweise": "0",
#     "Dachform und Dachneigung": "SD-DN 28-33°"
#   },
#   {
#     "Baugebiet": "WA",
#     "Zahl der Vollgeschosse": "II",
#     "Grundflächenzahl": "0,4",
#     "Geschossflächenzahl": "0,8",
#     "Bauweise": "0",
#     "Dachform und Dachneigung": "SD-DN 28-33°"
#   },
#   {
#     "Baugebiet": "WA",
#     "Zahl der Vollgeschosse": "I",
#     "Grundflächenzahl": "0,3",
#     "Geschossflächenzahl": "0,4",
#     "Bauweise": "0",
#     "Dachform und Dachneigung": "SD-DN 28-33°"
#   }
# ]
# ```
#
# ### Erläuterung der Werte in den Nutzungsschablonen
#
# 1. **Baugebiet**:
#    - **GE 2**: Eingeschränktes Gewerbegebiet für nicht wesentlich störende Gewerbebetriebe (§ 8 BauNVO)
#    - **WA**: Allgemeines Wohngebiet (§ 4 BauNVO)
#    - **MI**: Mischgebiet (§ 6 BauNVO)
#    - **WR**: Reines Wohngebiet (§ 3 BauNVO)
#
# 2. **Zahl der Vollgeschosse**:
#    - **I**: Ein Vollgeschoss
#    - **II**: Zwei Vollgeschosse
#    - Laut Textteil (§ 18 BauNVO und § 2 (4) LBO) ist die Zahl der Vollgeschosse entsprechend den Einzeichnungen im Plan festgelegt.
#
# 3. **Grundflächenzahl (GRZ)**:
#    - Gibt das Verhältnis der bebauten Fläche zur Grundstücksfläche an.
#    - Beispiel: Eine GRZ von 0,3 bedeutet, dass 30% der Grundstücksfläche bebaut werden dürfen.
#
# 4. **Geschossflächenzahl (GFZ)**:
#    - Gibt das Verhältnis der gesamten Geschossfläche zur Grundstücksfläche an.
#    - Beispiel: Eine GFZ von 0,5 bedeutet, dass die gesamte Geschossfläche 50% der Grundstücksfläche betragen darf.
#
# 5. **Bauweise**:
#    - **0**: Offene Bauweise (nur Einzel- und Doppelhäuser zulässig)
#    - **g**: Geschlossene Bauweise
#
# 6. **Dachform und Dachneigung**:
#    - **SD DN 12-18°**: Satteldach mit einer Dachneigung von 12-18 Grad
#    - **SD DN 28-33°**: Satteldach mit einer Dachneigung von 28-33 Grad
#    - **FD**: Flachdach
#
# Diese Werte sind gemäß den Festsetzungen in der Zeichenerklärung und dem Textteil des Bebauungsplans definiert.

# %%
# 2) Bebauungsplan F11-01
# %store -r msg212_f11_nz msg212_f11_ze msg222_f11_nz msg232_f11_tt
context = parser.text2prompts([f'Zeichenerklärung: {msg212_f11_nz}, {msg212_f11_ze}', f'Planzeichnung: {msg222_f11_nz}', f'Textteil: {msg232_f11_tt}'])
gerty.addContext(context)
msg2 = gerty.request([
    {
        "type": "text", 
        "text": "Wieviel Nutzungsschablonen enthält die Planzeichnung?"
    },
    {
        "type": "text", 
        "text": "Gebe alle Nutzungsschablonen im JSON Format aus."
    },
    {
        "type": "text", 
        "text": 'Erläutere die Werte in den Nutzungsschablonen anhand der Festsetzungen in der Zeichenerklärung und dem Textteil.'
    }
])
pprint(msg2)
gerty.clearContext()
# Out:
# Die Planzeichnung enthält vier Nutzungsschablonen. Hier sind die Nutzungsschablonen im JSON-Format:
#
# ```json
# [
#   {
#     "Art der Nutzung": "GEE*",
#     "Gebäudehöhe": "max. 12,00",
#     "Grundflächenzahl": "0,6",
#     "Geschossflächenzahl": "1,2",
#     "Bauweise": "a"
#   },
#   {
#     "Art der Nutzung": "GEE",
#     "Gebäudehöhe": "max. 12,00",
#     "Grundflächenzahl": "0,6",
#     "Geschossflächenzahl": "1,2",
#     "Bauweise": "a"
#   },
#   {
#     "Art der Nutzung": "GE",
#     "Gebäudehöhe": "max. 12,00",
#     "Grundflächenzahl": "0,6",
#     "Geschossflächenzahl": "1,2",
#     "Bauweise": "a"
#   },
#   {
#     "Art der Nutzung": "GE",
#     "Gebäudehöhe": "max. 12,00",
#     "Grundflächenzahl": "0,6",
#     "Geschossflächenzahl": "1,2",
#     "Bauweise": "a"
#   }
# ]
# ```
#
# ### Erläuterung der Werte in den Nutzungsschablonen:
#
# 1. **Art der Nutzung**:
#    - **GEE***: Eingeschränktes Gewerbegebiet mit zusätzlichen Einschränkungen.
#    - **GEE**: Eingeschränktes Gewerbegebiet gemäß § 8 BauNVO i.V.m. § 1 (4) BauNVO. Zulässig sind Gewerbebetriebe, die das Wohnen nicht wesentlich stören, wobei bei Einzelhandelsbetrieben nur die nicht innenstadtrelevanten Sortimente zulässig sind. Nicht zulässig sind Vergnügungsstätten und Einzelhandelsbetriebe mit innenstadtrelevanten Sortimenten.
#    - **GE**: Gewerbegebiet gemäß § 8 BauNVO. Zulässig sind Gewerbebetriebe aller Art, wobei bei Einzelhandelsbetrieben nur die nicht innenstadtrelevanten Sortimente zulässig sind. Nicht zulässig sind Vergnügungsstätten und Einzelhandelsbetriebe mit innenstadtrelevanten Sortimenten.
#
# 2. **Gebäudehöhe**:
#    - **max. 12,00**: Die maximale zulässige Gebäudehöhe beträgt 12,00 Meter über der Erdgeschossfußbodenhöhe. Diese wird gemessen von der Erdgeschossfußbodenhöhe bis zur Schnittkante zwischen Außenwand und Dachhaut bzw. bis zur Oberkante Firstziegel.
#
# 3. **Grundflächenzahl (GRZ)**:
#    - **0,6**: Die Grundflächenzahl gibt an, wie viel Quadratmeter Grundfläche je Quadratmeter Grundstücksfläche zulässig sind. Hier beträgt die GRZ 0,6, was bedeutet, dass 60% der Grundstücksfläche überbaut werden dürfen.
#
# 4. **Geschossflächenzahl (GFZ)**:
#    - **1,2**: Die Geschossflächenzahl gibt an, wie viel Quadratmeter Geschossfläche je Quadratmeter Grundstücksfläche zulässig sind. Hier beträgt die GFZ 1,2, was bedeutet, dass die gesamte Geschossfläche das 1,2-fache der Grundstücksfläche betragen darf.
#
# 5. **Bauweise**:
#    - **a**: Abweichende Bauweise gemäß § 22 BauNVO. Es gilt die offene Bauweise, jedoch sind die Gebäudelängen nicht begrenzt.

# %%
# 3) Bebauungsplan BP-872A
# %store -r msg213_bp872_nz msg213_bp872_ze msg233_bp872_tt_art msg233_bp872_tt_maß msg233_bp872_tt_bp
context = parser.text2prompts([f'Zeichenerklärung: {msg213_bp872_nz}, {msg213_bp872_ze}', f'Textteil: {msg233_bp872_tt_art}, {msg233_bp872_tt_maß},{msg233_bp872_tt_bp}'])
gerty.addContext(context)
msg3 = gerty.request([
    {
        "type": "text", 
        "text": "Gebe das Schema der Nutzungsschablone in der Zeichenerklärung aus."
    },
    {
        "type": "text", 
        "text": 'Erläutere die Werte in den Nutzungsschablonen anhand der Festsetzungen in der Zeichenerklärung und dem Textteil.'
    }
])
pprint(msg3)
gerty.clearContext()
# Out:
# ### Schema der Nutzungsschablone in der Zeichenerklärung
#
# +----------------+------------------+
# | Art der baulichen Nutzung         |
# +----------------+------------------+
# | Grundflächenzahl| Geschossflächen-|
# | (GRZ)          | zahl (GF)       |
# +----------------+------------------+
#
# ### Erläuterung der Werte in den Nutzungsschablonen
#
# #### Art der baulichen Nutzung
#
# - **WA1**: Allgemeines Wohngebiet mit Nummerierung
#
# #### Maß der baulichen Nutzung
#
# - **GF 5250**: Geschossfläche (GF) als Höchstmaß
# - **0,35**: Grundflächenzahl (GRZ) als Höchstmaß
# - **IV**: Zahl der Vollgeschosse, zwingend
# - **IV**: Zahl der Vollgeschosse als Höchstmaß
# - **OK 12,5**: Oberkante (OK) baulicher Anlagen in Meter zwingend, bezogen auf einen Bezugspunkt gemäß textlicher Festsetzung
# - **OK 12,5**: Oberkante (OK) baulicher Anlagen in Meter als Höchstmaß, bezogen auf einen Bezugspunkt gemäß textlicher Festsetzung
#
# #### Bauweise, überbaubare Grundstücksfläche
#
# - **g**: Geschlossene Bauweise
# - **Baulinie**: (Symbol: rote Linie)
# - **Baugrenze**: (Symbol: blaue Linie)
#
# ### Erläuterung anhand der Festsetzungen in der Zeichenerklärung und dem Textteil
#
# 1. **Art der baulichen Nutzung (WA1)**:
#    - Das Gebiet ist als Allgemeines Wohngebiet (WA) gemäß § 4 BauNVO festgesetzt. Dies bedeutet, dass in diesem Gebiet hauptsächlich Wohngebäude zulässig sind. Zusätzlich sind Läden, Schank- und Speisewirtschaften, nicht störende Handwerksbetriebe sowie Anlagen für kirchliche, kulturelle, soziale, gesundheitliche und sportliche Zwecke erlaubt. Betriebe des Beherbergungsgewerbes, sonstige nicht störende Gewerbebetriebe, Anlagen für Verwaltungen, Gartenbaubetriebe und Tankstellen sind nicht zulässig.
#
# 2. **Maß der baulichen Nutzung**:
#    - **GF 5250**: Die maximale Geschossfläche (GF) beträgt 5250 Quadratmeter.
#    - **0,35**: Die Grundflächenzahl (GRZ) beträgt maximal 0,35. Dies bedeutet, dass maximal 35% der Grundstücksfläche überbaut werden dürfen.
#    - **IV**: Die Zahl der Vollgeschosse ist auf vier festgelegt, sowohl als zwingendes Maß als auch als Höchstmaß.
#    - **OK 12,5**: Die Oberkante (OK) der baulichen Anlagen darf maximal 12,5 Meter betragen, bezogen auf einen festgelegten Bezugspunkt.
#
# 3. **Bauweise, überbaubare Grundstücksfläche**:
#    - **g**: Die Bauweise ist geschlossen, was bedeutet, dass die Gebäude ohne seitlichen Grenzabstand aneinandergebaut werden müssen.
#    - **Baulinie**: Die rote Linie in der Planzeichnung markiert die Baulinie, an der die Gebäude zwingend errichtet werden müssen.
#    - **Baugrenze**: Die blaue Linie in der Planzeichnung markiert die Baugrenze, bis zu der die Gebäude errichtet werden dürfen.
#
# Diese Festsetzungen und Begründungen orientieren sich an der bestehenden Nutzungsstruktur und zielen darauf ab, ein hochwertiges innerstädtisches Wohnquartier zu schaffen.

# %% [markdown]
# ### Use-Case Grüber Prüfschema (L04-01)

# %%
# %store -r msg211_l04_nz msg211_l04_ze msg221_l04_nz msg231_l04_tt
context = parser.text2prompts([f'Zeichenerklärung: {msg211_l04_nz}, {msg211_l04_ze}', f'Planzeichnung: {msg221_l04_nz}', f'Textliche Festsetzungen: {msg231_l04_tt}'])
gerty.addContext(context)
def run():
    return gerty.request([
        {
            "type": "text", 
            "text": "Welche Gebäudearten sind erlaubt?"
        },
        {
            "type": "text", 
            "text": "Ist ein Wohnhaus erlaubt?"
        },
        {
            "type": "text", 
            "text": "Welche GRZ und GFZ sind festgesetzt?"
        },
        {
            "type": "text", 
            "text": "Liegen die Werte GRZ von 0,17 und ein GFZ von 0.35 unter den maximal erlaubten Werten?"
        },
        {
            "type": "text", 
            "text": "Wieviel Vollgeschosse sind erlaubt?"
        },
        {
            "type": "text", 
            "text": "Sind zwei Vollgeschosse zulässig?"
        },
        {
            "type": "text", 
            "text": "Welche Bauweisen sind festgesetzt?"
        },
        {
            "type": "text", 
            "text": "Ist eine seitliche Abstandsfläche zulässig?"
        },
        {
            "type": "text", 
            "text": "Welche Bauweise ist für Wohngebäude zulässig?"
        },
    ])
runner.consistency_check(run)
gerty.clearContext()
# Out:
# ### Erlaubte Gebäudearten
# - **Wohnbauflächen**
#   - **WR**: Reines Wohngebiet (§ 3 BauNVO)
#   - **WA**: Allgemeines Wohngebiet (§ 4 BauNVO)
# - **Gemischte Bauflächen**
#   - **MI**: Mischgebiet (§ 6 BauNVO)
#   - **GE2**: Eingeschränktes Gewerbegebiet für nicht wesentlich störende Gewerbebetriebe (§ 8 BauNVO)
#
# ### Ist ein Wohnhaus erlaubt?
# Ja, ein Wohnhaus ist in den Baugebieten **WR** (Reines Wohngebiet) und **WA** (Allgemeines Wohngebiet) erlaubt.
#
# ### Festgesetzte GRZ und GFZ
# Die festgesetzten Werte für die Grundflächenzahl (GRZ) und Geschossflächenzahl (GFZ) variieren je nach Baugebiet:
# - **GE 2**: GRZ 0,6, GFZ 1,2
# - **WA**: GRZ 0,3 bis 0,5, GFZ 0,4 bis 0,8
# - **MI**: GRZ 0,4, GFZ 0,5
# - **WR**: GRZ 0,3 bis 0,5, GFZ 0,5
#
# ### Liegen die Werte GRZ von 0,17 und GFZ von 0.35 unter den maximal erlaubten Werten?
# Ja, die Werte GRZ von 0,17 und GFZ von 0.35 liegen unter den maximal erlaubten Werten in allen genannten Baugebieten.
#
# ### Erlaubte Vollgeschosse
# Die Anzahl der erlaubten Vollgeschosse variiert je nach Baugebiet:
# - **GE 2**: II Vollgeschosse
# - **WA**: I bis II Vollgeschosse
# - **MI**: I bis II Vollgeschosse
# - **WR**: I Vollgeschoss
#
# ### Sind zwei Vollgeschosse zulässig?
# Ja, zwei Vollgeschosse sind in den Baugebieten **GE 2**, **WA** (in einigen Fällen), und **MI** zulässig.
#
# ### Festgesetzte Bauweisen
# Die festgesetzten Bauweisen sind:
# - **Offene Bauweise**: Nur Einzel- und Doppelhäuser zulässig
# - **Geschlossene Bauweise**
#
# ### Ist eine seitliche Abstandsfläche zulässig?
# Das ist mir nicht bekannt.
#
# ### Zulässige Bauweise für Wohngebäude
# Für Wohngebäude ist die **offene Bauweise** zulässig, in der nur Einzel- und Doppelhäuser erlaubt sind.
# #############################################
# ### Erlaubte Gebäudearten
# Die erlaubten Gebäudearten sind abhängig vom Baugebiet:
# - **WR**: Reines Wohngebiet
# - **WA**: Allgemeines Wohngebiet
# - **MI**: Mischgebiet
# - **GE2**: Eingeschränktes Gewerbegebiet für nicht wesentlich störende Gewerbebetriebe
#
# ### Ist ein Wohnhaus erlaubt?
# Ja, ein Wohnhaus ist in den Baugebieten **WR** (Reines Wohngebiet) und **WA** (Allgemeines Wohngebiet) erlaubt.
#
# ### Festgesetzte GRZ und GFZ
# Die festgesetzten Werte für die Grundflächenzahl (GRZ) und Geschossflächenzahl (GFZ) variieren je nach Baugebiet:
# - **GE2**: GRZ 0,6, GFZ 1,2
# - **WA**: GRZ 0,3 bis 0,5, GFZ 0,4 bis 0,8
# - **MI**: GRZ 0,4, GFZ 0,5
# - **WR**: GRZ 0,3 bis 0,5, GFZ 0,5
#
# ### Liegen die Werte GRZ von 0,17 und GFZ von 0,35 unter den maximal erlaubten Werten?
# Ja, die Werte GRZ von 0,17 und GFZ von 0,35 liegen unter den maximal erlaubten Werten in allen genannten Baugebieten.
#
# ### Erlaubte Vollgeschosse
# Die Anzahl der erlaubten Vollgeschosse variiert je nach Baugebiet:
# - **GE2**: II Vollgeschosse
# - **WA**: I oder II Vollgeschosse
# - **MI**: I oder II Vollgeschosse
# - **WR**: I Vollgeschoss
#
# ### Sind zwei Vollgeschosse zulässig?
# Ja, zwei Vollgeschosse sind in den Baugebieten **GE2**, **WA** (teilweise), und **MI** zulässig.
#
# ### Festgesetzte Bauweisen
# Die festgesetzten Bauweisen sind:
# - **Offene Bauweise**: Nur Einzel- und Doppelhäuser zulässig
# - **Geschlossene Bauweise**
#
# ### Seitliche Abstandsfläche
# Das ist mir nicht bekannt.
#
# ### Bauweise für Wohngebäude
# Für Wohngebäude ist die **offene Bauweise** festgesetzt, in der nur Einzel- und Doppelhäuser zulässig sind.
# #############################################
# ### Erlaubte Gebäudearten
# Die erlaubten Gebäudearten sind abhängig von der Art der baulichen Nutzung des jeweiligen Baugebiets:
# - **Wohnbauflächen**:
#   - **WR**: Reines Wohngebiet
#   - **WA**: Allgemeines Wohngebiet
# - **Gemischte Bauflächen**:
#   - **MI**: Mischgebiet
#   - **GE2**: Eingeschränktes Gewerbegebiet für nicht wesentlich störende Gewerbebetriebe
#
# ### Wohnhaus
# Ja, ein Wohnhaus ist in den Baugebieten **WR** (Reines Wohngebiet) und **WA** (Allgemeines Wohngebiet) erlaubt.
#
# ### GRZ und GFZ
# Die festgesetzten Werte für die Grundflächenzahl (GRZ) und Geschossflächenzahl (GFZ) variieren je nach Baugebiet:
# - **GE2**: GRZ 0,6, GFZ 1,2
# - **WA**: GRZ 0,3 bis 0,5, GFZ 0,4 bis 0,8
# - **MI**: GRZ 0,4, GFZ 0,5
# - **WR**: GRZ 0,3 bis 0,5, GFZ 0,5
#
# ### Vergleich der Werte
# Die Werte GRZ von 0,17 und GFZ von 0,35 liegen unter den maximal erlaubten Werten in allen genannten Baugebieten.
#
# ### Erlaubte Vollgeschosse
# Die Anzahl der erlaubten Vollgeschosse variiert je nach Baugebiet:
# - **GE2**: II Vollgeschosse
# - **WA**: I oder II Vollgeschosse
# - **MI**: I oder II Vollgeschosse
# - **WR**: I Vollgeschoss
#
# ### Zwei Vollgeschosse
# Ja, zwei Vollgeschosse sind in den Baugebieten **GE2**, **WA** (teilweise), und **MI** zulässig.
#
# ### Festgesetzte Bauweisen
# Die festgesetzten Bauweisen sind:
# - **Offene Bauweise**: Nur Einzel- und Doppelhäuser zulässig
# - **Geschlossene Bauweise**
#
# ### Seitliche Abstandsfläche
# Das ist mir nicht bekannt.
#
# ### Bauweise für Wohngebäude
# Für Wohngebäude ist die **offene Bauweise** festgesetzt, in der nur Einzel- und Doppelhäuser zulässig sind.
# #############################################
